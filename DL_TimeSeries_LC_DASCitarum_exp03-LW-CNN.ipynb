# %%
import tensorflow as tf
tf.__version__
tf.keras.backend.clear_session()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.backend import sigmoid
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Layer, Permute, multiply
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Conv1D, Dropout, Dense, BatchNormalization, ReLU, Flatten
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Lambda, Reshape, Activation, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Add, MaxPooling1D, MultiHeadAttention, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import sklearn
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight

# %%
# data_b2= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B2_final.csv')
# data_b3= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B3_final.csv')
# data_b4= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B4_final.csv')
# data_b5= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B5_final.csv')
# data_b6= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B6_final.csv')
# data_b7= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B7_final.csv')
# data_b8= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B8_final.csv')
# data_b8A= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B8A_final.csv')
# data_b11= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B11_final.csv')
# data_b12= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B12_final.csv')

data_cbi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/CBI_final.csv')
data_bsi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/BSI_final.csv')
data_evi2= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/EVI2_final.csv')
data_mndwi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/MNDWI_final.csv')
data_msavi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/MSAVI_final.csv')
data_nbr= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/NBR_final.csv')
data_ndvi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/NDVI_final.csv')

# %%
#interpolate NaN for each row
# data_b2 = data_b2.apply(pd.to_numeric, errors='coerce')
# data_b3 = data_b3.apply(pd.to_numeric, errors='coerce')
# data_b4 = data_b4.apply(pd.to_numeric, errors='coerce')
# data_b5 = data_b5.apply(pd.to_numeric, errors='coerce')
# data_b6 = data_b6.apply(pd.to_numeric, errors='coerce')
# data_b7 = data_b7.apply(pd.to_numeric, errors='coerce')
# data_b8 = data_b8.apply(pd.to_numeric, errors='coerce')
# data_b8A = data_b8A.apply(pd.to_numeric, errors='coerce')
# data_b11 = data_b11.apply(pd.to_numeric, errors='coerce')
# data_b12 = data_b12.apply(pd.to_numeric, errors='coerce')

data_cbi_ = data_cbi.values
data_bsi_ = data_bsi.values
data_evi2_ = data_evi2.values
data_mndwi_ = data_mndwi.values
data_msavi_ = data_msavi.values
data_nbr_ = data_nbr.values
data_ndvi_ = data_ndvi.values

cbi_pd = pd.DataFrame(data_cbi_)
bsi_pd = pd.DataFrame(data_bsi_)
evi2_pd = pd.DataFrame(data_evi2_)
mndwi_pd = pd.DataFrame(data_mndwi_)
msavi_pd = pd.DataFrame(data_msavi_)
nbr_pd = pd.DataFrame(data_nbr_)
ndvi_pd = pd.DataFrame(data_ndvi_)

cbi_pd = cbi_pd.iloc[:,3:42].astype(float)
bsi_pd = bsi_pd.iloc[:,3:42].astype(float)
evi2_pd  = evi2_pd.iloc[:,3:42].astype(float)
mndwi_pd  = mndwi_pd.iloc[:,3:42].astype(float)
msavi_pd = msavi_pd.iloc[:,3:42].astype(float)
nbr_pd  = nbr_pd.iloc[:,3:42].astype(float)
ndvi_pd  = ndvi_pd.iloc[:,3:42].astype(float)

# data_b2_int = data_b2.interpolate(method='linear', limit_direction='both', axis=1)
# data_b3_int = data_b3.interpolate(method='linear', limit_direction='both', axis=1)
# data_b4_int = data_b4.interpolate(method='linear', limit_direction='both', axis=1)
# data_b5_int = data_b5.interpolate(method='linear', limit_direction='both', axis=1)
# data_b6_int = data_b6.interpolate(method='linear', limit_direction='both', axis=1)
# data_b7_int = data_b7.interpolate(method='linear', limit_direction='both', axis=1)
# data_b8_int = data_b8.interpolate(method='linear', limit_direction='both', axis=1)
# data_b8A_int = data_b8A.interpolate(method='linear', limit_direction='both', axis=1)
# data_b11_int = data_b11.interpolate(method='linear', limit_direction='both', axis=1)
# data_b12_int = data_b12.interpolate(method='linear', limit_direction='both', axis=1)

data_cbi_int = cbi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_bsi_int = bsi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_evi2_int = evi2_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_mndwi_int = mndwi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_msavi_int = msavi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_nbr_int = nbr_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_ndvi_int = ndvi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)

# print('Number of nan for B2 after:', data_b2_int.isnull().sum().sum())
# print('Number of nan for B3 after:', data_b3_int.isnull().sum().sum())
# print('Number of nan for B4 after:', data_b4_int.isnull().sum().sum())
# print('Number of nan for B5 after:', data_b5_int.isnull().sum().sum())
# print('Number of nan for B6 after:', data_b6_int.isnull().sum().sum())
# print('Number of nan for B7 after:', data_b7_int.isnull().sum().sum())
# print('Number of nan for B8 after:', data_b8_int.isnull().sum().sum())
# print('Number of nan for B8A after:', data_b8A_int.isnull().sum().sum())
# print('Number of nan for B11 after:', data_b11_int.isnull().sum().sum())
# print('Number of nan for B12 after:', data_b12_int.isnull().sum().sum())

print('Number of nan for CBI after:', np.count_nonzero(np.isnan(data_cbi_int)))
print('Number of nan for BSI after:', np.count_nonzero(np.isnan(data_bsi_int)))
print('Number of nan for EVI2 after:', np.count_nonzero(np.isnan(data_evi2_int)))
print('Number of nan for MNDWI after:', data_mndwi_int.isnull().sum().sum())
print('Number of nan for MSAVI after:', data_msavi_int.isnull().sum().sum())
print('Number of nan for NBR after:', data_nbr_int.isnull().sum().sum())
print('Number of nan for NDVI after:', data_ndvi_int.isnull().sum().sum())
# Out:
# Number of nan for CBI after: 0
# Number of nan for BSI after: 0
# Number of nan for EVI2 after: 0
# Number of nan for MNDWI after: 0
# Number of nan for MSAVI after: 0
# Number of nan for NBR after: 0
# Number of nan for NDVI after: 0

# %%
# print(data_cbi_int.max())
# print(data_bsi_int.max())
# print(data_evi2_int.max())
# print(data_mndwi_int.max())
# print(data_msavi_int.max())
# print(data_nbr_int.max())
# print(data_ndvi_int.max())

# %%
comb_all = pd.concat([data_cbi_int, data_bsi_int, data_evi2_int,
                      data_mndwi_int, data_msavi_int, 
                      data_nbr_int, data_ndvi_int], axis =0, ignore_index=True)

# %%
comb_all_lc = pd.concat([data_cbi.iloc[:,0:3], data_bsi.iloc[:,0:3], data_evi2.iloc[:,0:3],
                            data_mndwi.iloc[:,0:3], data_msavi.iloc[:,0:3],
                            data_nbr.iloc[:,0:3], data_ndvi.iloc[:,0:3]], axis =0, ignore_index=True)

# %%
# print(comb_all_lc)

# %%
# print(comb_all_lc.Class.value_counts())

# %%
y = data_cbi.iloc[:,2]
y = np.asarray(y).astype(np.float32)
y_cat = to_categorical(y)
y_cat = y_cat[:,1:8] # num_class + 1

# %%
# print(y.shape)

# %%
# print(y_cat)
# print(y_cat.shape)

# %%
# print(np.unique(y))

# %%
class_weights = compute_class_weight(class_weight = "balanced",
                                      classes = np.unique(y), y=y)
class_weights = dict(enumerate(class_weights))
# class_weights = dict(zip(np.unique(train_classes), class_weights))
print(class_weights)
# Out:
# {0: 1.2355889724310778, 1: 0.985014985014985, 2: 0.4977284199899041, 3: 2.9969604863221884, 4: 1.5916061339790153, 5: 0.8072042570609906, 6: 1.0357142857142858}

# %%
# print(comb_all.shape)
# print(comb_all)

# %%
# comb_b2 = comb_all.iloc[0:1939:,3:31]
# comb_b3 = comb_all.iloc[1939:3878:,3:31]
# comb_b4 = comb_all.iloc[3878:5817:,3:31]
# comb_b5 = comb_all.iloc[5817:7756:,3:31]
# comb_b6 = comb_all.iloc[7756:9695:,3:31]
# comb_b7 = comb_all.iloc[9695:11634:,3:31]
# comb_b8 = comb_all.iloc[11634:13573:,3:31]
# comb_b8A = comb_all.iloc[13573:15512:,3:31]
# comb_b11 = comb_all.iloc[15512:17451:,3:31]
# comb_b12 = comb_all.iloc[17451:19390:,3:31]

comb_cbi = comb_all.iloc[0:1972:,:]
comb_bsi = comb_all.iloc[1972:3944:,:]
comb_evi2 = comb_all.iloc[3944:5916:,:]
comb_mndwi = comb_all.iloc[5916:7888:,:]
comb_msavi = comb_all.iloc[7888:9860:,:]
comb_nbr = comb_all.iloc[9860:11832:,:]
comb_ndvi = comb_all.iloc[11832:13804:,:]

# comb_b2= np.asarray(comb_b2).astype(np.float32)
# comb_b3= np.asarray(comb_b3).astype(np.float32)
# comb_b4= np.asarray(comb_b4).astype(np.float32)
# comb_b5= np.asarray(comb_b5).astype(np.float32)
# comb_b6= np.asarray(comb_b6).astype(np.float32)
# comb_b7= np.asarray(comb_b7).astype(np.float32)
# comb_b8= np.asarray(comb_b8).astype(np.float32)
# comb_b8A= np.asarray(comb_b8A).astype(np.float32)
# comb_b11= np.asarray(comb_b11).astype(np.float32)
# comb_b12= np.asarray(comb_b12).astype(np.float32)

comb_cbi= np.asarray(comb_cbi).astype(np.float64)
comb_bsi= np.asarray(comb_bsi).astype(np.float64)
comb_evi2= np.asarray(comb_evi2).astype(np.float64)
comb_mndwi= np.asarray(comb_mndwi).astype(np.float64)
comb_msavi= np.asarray(comb_msavi).astype(np.float64)
comb_nbr= np.asarray(comb_nbr).astype(np.float64)
comb_ndvi= np.asarray(comb_ndvi).astype(np.float64)

# %%
comb_stack = np.stack((comb_cbi, comb_bsi, comb_evi2,
                       comb_mndwi, comb_msavi, comb_nbr, 
                       comb_ndvi), axis=1)

# comb_stack = np.stack((comb_cbi, comb_bsi, comb_evi2), axis=1)
# print(comb_stack.shape)

comb_stack_reshape = comb_stack.reshape(comb_stack.shape[0], comb_stack.shape[2], comb_stack.shape[1])
print(comb_stack_reshape.shape)

X_train, X_test, y_train, y_test = train_test_split(comb_stack_reshape , y_cat, test_size=0.30, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1972, 39, 7)
# (1380, 39, 7) (1380, 7) (592, 39, 7) (592, 7)

# %%
# print(comb_cbi.shape)

# %%
# stack_ver = np.hstack((vert_cbi, vert_bsi, vert_evi2,
#                        vert_mndwi, vert_msavi, vert_nbr, 
#                        vert_ndvi))
# print(stack_ver.shape)

# %%
# import seaborn as sns 

# x = ['CBI','BSI','EVI2', 'MNDWI', 'MSAVI', 'NBR', 'NDVI']
# # enumerate label
# for i in enumerate(x):
#     print(i)

# # plot correlation matrix
# rf_pd = pd.DataFrame(data=stack_ver, columns=list(x))
# matrix = np.triu(rf_pd.corr())
# plt.figure(figsize=(12,8))
# sns.heatmap(rf_pd.corr(), annot=True, mask=matrix)

# %%
num_classes = len(np.unique(y))
input_shape=(X_train.shape[1], X_train.shape[2])
print(num_classes)
print(input_shape)
# Out:
# 7
# (39, 7)

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Metric

class CustomMeanIoU(Metric):
    def __init__(self, num_classes, name='custom_mean_iou', **kwargs):
        super(CustomMeanIoU, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.confusion_matrix = self.add_weight(
            'confusion_matrix',
            shape=(num_classes, num_classes),
            initializer='zeros',
            dtype=tf.float32)
            
    def update_state(self, y_true, y_pred, sample_weight=None):
        # First, ensure y_pred is class indices (argmax) and cast to int32
        if len(tf.shape(y_pred)) > 1 and tf.shape(y_pred)[-1] > 1:
            y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
        else:
            # If not one-hot, ensure it's still int32
            y_pred = tf.cast(y_pred, tf.int32)
        
        # Then ensure y_true is the same format (class indices as int32)
        if len(tf.shape(y_true)) > 1 and tf.shape(y_true)[-1] > 1:
            y_true = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)
        else:
            # If not one-hot, ensure it's still int32
            y_true = tf.cast(y_true, tf.int32)
            
        # Convert to 1D tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])
        
        # Calculate confusion matrix
        cm_update = tf.math.confusion_matrix(
            y_true, y_pred, self.num_classes, 
            dtype=tf.float32)
        
        # Update the total confusion matrix
        self.confusion_matrix.assign_add(cm_update)
        
    def result(self):
        cm = self.confusion_matrix
        
        # Extract per-class TP, FP, FN
        tp = tf.linalg.diag_part(cm)
        sum_over_row = tf.reduce_sum(cm, axis=1)
        sum_over_col = tf.reduce_sum(cm, axis=0)
        fp = sum_over_col - tp
        fn = sum_over_row - tp
        
        # Calculate IoU per class
        denominator = tp + fp + fn
        
        # Avoid division by zero
        iou = tf.math.divide_no_nan(tp, denominator)
        
        # Calculate mean IoU (average over classes)
        valid_classes = tf.cast(denominator > 0, tf.float32)
        num_valid = tf.reduce_sum(valid_classes)
        
        # Return mean IoU
        return tf.math.divide_no_nan(tf.reduce_sum(iou), num_valid)
        
    def reset_state(self):
        # Reset the confusion matrix at the start of each epoch
        self.confusion_matrix.assign(tf.zeros((self.num_classes, self.num_classes)))

    def get_config(self):
        config = super(CustomMeanIoU, self).get_config()
        config.update({"num_classes": self.num_classes})
        return config

# %%
# %%time
#Best set up

def make_model(input_shape):
    input_layer = Input(input_shape)
    
    x0 = Conv1D(32, 3, activation="relu", padding='same')(input_layer)
    
    x01 = Conv1D(64, 3, activation="relu", padding='same')(x0)
    x01 = BatchNormalization()(x01)
    x02 = Conv1D(64, 3, activation="relu", padding='same')(x01)
    x03 = Conv1D(64, 3, activation="relu", padding='same')(x02)
    
    add01 = tf.keras.layers.add([x01, x03])
    max01 = MaxPooling1D(strides = 2)(add01)
    
    x01a = Conv1D(64, 3, activation="relu", padding='same')(max01)
    x01a = BatchNormalization()(x01a)
    x02a = Conv1D(64, 3, activation="relu", padding='same')(x01a)
    x03a = Conv1D(64, 3, activation="relu", padding='same')(x02a)
    
    add01a = tf.keras.layers.add([x01a, x03a])
    max01a = MaxPooling1D(strides = 2)(add01a)
    
    fc = Flatten()(max01a)
    fc = Dense(768, activation="relu")(fc)

    output_layer = Dense(num_classes, activation="softmax")(fc)

    return Model(inputs=input_layer, outputs=output_layer)

model = make_model(input_shape= input_shape)
model.summary()
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                    optimizer=optimizers.RMSprop(learning_rate=0.001), 
                    metrics=[CustomMeanIoU(num_classes=7)])

checkpoint = ModelCheckpoint(filepath='D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model/LC_DAS_Citarum_exp03_LWCNN_mIoU.h5',
                              monitor='val_custom_mean_iou',save_best_only=True,verbose=1,mode='max')
early_stop = EarlyStopping(monitor='val_custom_mean_iou',patience=100,restore_best_weights=True,mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_custom_mean_iou', factor=0.1,patience=30, min_lr=0.00001)

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size =20,
                    epochs=500, callbacks = [checkpoint, early_stop, reduce_lr], 
                    class_weight=class_weights)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 39, 7)]              0         []
#
#  conv1d (Conv1D)             (None, 39, 32)               704       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 39, 64)               6208      ['conv1d[0][0]']
#
#  batch_normalization (Batch  (None, 39, 64)               256       ['conv1d_1[0][0]']
#  Normalization)
#
#  conv1d_2 (Conv1D)           (None, 39, 64)               12352     ['batch_normalization[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 39, 64)               12352     ['conv1d_2[0][0]']
#
#  add (Add)                   (None, 39, 64)               0         ['batch_normalization[0][0]',
#                                                                      'conv1d_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 19, 64)               0         ['add[0][0]']
#  D)
#
#  conv1d_4 (Conv1D)           (None, 19, 64)               12352     ['max_pooling1d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 19, 64)               256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 19, 64)               12352     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_6 (Conv1D)           (None, 19, 64)               12352     ['conv1d_5[0][0]']
#
#  add_1 (Add)                 (None, 19, 64)               0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 9, 64)                0         ['add_1[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 576)                  0         ['max_pooling1d_1[0][0]']
#
#  dense (Dense)               (None, 768)                  443136    ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    5383      ['dense[0][0]']
#
# ==================================================================================================
# Total params: 517703 (1.97 MB)
# Trainable params: 517447 (1.97 MB)
# Non-trainable params: 256 (1.00 KB)
# __________________________________________________________________________________________________
# Epoch 1/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.2038 - custom_mean_iou: 0.5514
# Epoch 1: val_custom_mean_iou improved from -inf to 0.03233, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# D:\anaconda\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/69 [==============================] - 5s 34ms/step - loss: 1.2008 - custom_mean_iou: 0.5493 - val_loss: 1.9758 - val_custom_mean_iou: 0.0323 - lr: 0.0010
# Epoch 2/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4041 - custom_mean_iou: 0.7429
# Epoch 2: val_custom_mean_iou did not improve from 0.03233
# 69/69 [==============================] - 1s 16ms/step - loss: 0.4041 - custom_mean_iou: 0.7429 - val_loss: 2.1140 - val_custom_mean_iou: 0.0250 - lr: 0.0010
# Epoch 3/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.3255 - custom_mean_iou: 0.8001
# Epoch 3: val_custom_mean_iou improved from 0.03233 to 0.09511, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3661 - custom_mean_iou: 0.8001 - val_loss: 2.2021 - val_custom_mean_iou: 0.0951 - lr: 0.0010
# Epoch 4/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2487 - custom_mean_iou: 0.8270
# Epoch 4: val_custom_mean_iou improved from 0.09511 to 0.13034, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 0.2458 - custom_mean_iou: 0.8275 - val_loss: 2.3470 - val_custom_mean_iou: 0.1303 - lr: 0.0010
# Epoch 5/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1786 - custom_mean_iou: 0.8864
# Epoch 5: val_custom_mean_iou improved from 0.13034 to 0.22176, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 3s 42ms/step - loss: 0.1786 - custom_mean_iou: 0.8869 - val_loss: 1.7252 - val_custom_mean_iou: 0.2218 - lr: 0.0010
# Epoch 6/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.1755 - custom_mean_iou: 0.8910
# Epoch 6: val_custom_mean_iou improved from 0.22176 to 0.43330, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.1722 - custom_mean_iou: 0.8926 - val_loss: 1.1917 - val_custom_mean_iou: 0.4333 - lr: 0.0010
# Epoch 7/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1754 - custom_mean_iou: 0.9059
# Epoch 7: val_custom_mean_iou improved from 0.43330 to 0.51664, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 25ms/step - loss: 0.1754 - custom_mean_iou: 0.9059 - val_loss: 0.8059 - val_custom_mean_iou: 0.5166 - lr: 0.0010
# Epoch 8/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1021 - custom_mean_iou: 0.9269
# Epoch 8: val_custom_mean_iou improved from 0.51664 to 0.74277, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0977 - custom_mean_iou: 0.9295 - val_loss: 0.3372 - val_custom_mean_iou: 0.7428 - lr: 0.0010
# Epoch 9/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.1138 - custom_mean_iou: 0.9297
# Epoch 9: val_custom_mean_iou improved from 0.74277 to 0.86389, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 32ms/step - loss: 0.1128 - custom_mean_iou: 0.9264 - val_loss: 0.1822 - val_custom_mean_iou: 0.8639 - lr: 0.0010
# Epoch 10/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0554 - custom_mean_iou: 0.9591
# Epoch 10: val_custom_mean_iou did not improve from 0.86389
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0675 - custom_mean_iou: 0.9525 - val_loss: 0.2185 - val_custom_mean_iou: 0.8263 - lr: 0.0010
# Epoch 11/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0789 - custom_mean_iou: 0.9567
# Epoch 11: val_custom_mean_iou improved from 0.86389 to 0.88973, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0789 - custom_mean_iou: 0.9567 - val_loss: 0.1758 - val_custom_mean_iou: 0.8897 - lr: 0.0010
# Epoch 12/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0889 - custom_mean_iou: 0.9421
# Epoch 12: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0889 - custom_mean_iou: 0.9421 - val_loss: 0.4933 - val_custom_mean_iou: 0.8062 - lr: 0.0010
# Epoch 13/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0888 - custom_mean_iou: 0.9385
# Epoch 13: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0937 - custom_mean_iou: 0.9338 - val_loss: 0.2264 - val_custom_mean_iou: 0.8896 - lr: 0.0010
# Epoch 14/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0277 - custom_mean_iou: 0.9775
# Epoch 14: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0296 - custom_mean_iou: 0.9772 - val_loss: 0.5116 - val_custom_mean_iou: 0.8165 - lr: 0.0010
# Epoch 15/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0772 - custom_mean_iou: 0.9616
# Epoch 15: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0772 - custom_mean_iou: 0.9616 - val_loss: 0.2871 - val_custom_mean_iou: 0.8561 - lr: 0.0010
# Epoch 16/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0488 - custom_mean_iou: 0.9731
# Epoch 16: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0572 - custom_mean_iou: 0.9721 - val_loss: 0.3925 - val_custom_mean_iou: 0.8091 - lr: 0.0010
# Epoch 17/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0515 - custom_mean_iou: 0.9705
# Epoch 17: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0515 - custom_mean_iou: 0.9705 - val_loss: 0.6519 - val_custom_mean_iou: 0.7960 - lr: 0.0010
# Epoch 18/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0432 - custom_mean_iou: 0.9679
# Epoch 18: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0505 - custom_mean_iou: 0.9663 - val_loss: 0.3244 - val_custom_mean_iou: 0.8550 - lr: 0.0010
# Epoch 19/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0335 - custom_mean_iou: 0.9787
# Epoch 19: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0362 - custom_mean_iou: 0.9731 - val_loss: 0.3792 - val_custom_mean_iou: 0.8434 - lr: 0.0010
# Epoch 20/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0715 - custom_mean_iou: 0.9679
# Epoch 20: val_custom_mean_iou did not improve from 0.88973
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0715 - custom_mean_iou: 0.9679 - val_loss: 0.4090 - val_custom_mean_iou: 0.8682 - lr: 0.0010
# Epoch 21/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0232 - custom_mean_iou: 0.9823
# Epoch 21: val_custom_mean_iou improved from 0.88973 to 0.91786, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0222 - custom_mean_iou: 0.9830 - val_loss: 0.2038 - val_custom_mean_iou: 0.9179 - lr: 0.0010
# Epoch 22/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0326 - custom_mean_iou: 0.9818
# Epoch 22: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0312 - custom_mean_iou: 0.9826 - val_loss: 0.2427 - val_custom_mean_iou: 0.8851 - lr: 0.0010
# Epoch 23/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.0814 - custom_mean_iou: 0.9600
# Epoch 23: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0802 - custom_mean_iou: 0.9602 - val_loss: 0.1918 - val_custom_mean_iou: 0.9170 - lr: 0.0010
# Epoch 24/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0804 - custom_mean_iou: 0.9555
# Epoch 24: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0782 - custom_mean_iou: 0.9570 - val_loss: 0.2958 - val_custom_mean_iou: 0.8891 - lr: 0.0010
# Epoch 25/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0439 - custom_mean_iou: 0.9690
# Epoch 25: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0439 - custom_mean_iou: 0.9690 - val_loss: 0.4089 - val_custom_mean_iou: 0.8907 - lr: 0.0010
# Epoch 26/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.0557 - custom_mean_iou: 0.9696
# Epoch 26: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0550 - custom_mean_iou: 0.9699 - val_loss: 0.3162 - val_custom_mean_iou: 0.8779 - lr: 0.0010
# Epoch 27/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0760 - custom_mean_iou: 0.9605
# Epoch 27: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0738 - custom_mean_iou: 0.9622 - val_loss: 0.3073 - val_custom_mean_iou: 0.8670 - lr: 0.0010
# Epoch 28/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0619 - custom_mean_iou: 0.9633
# Epoch 28: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0601 - custom_mean_iou: 0.9645 - val_loss: 0.2654 - val_custom_mean_iou: 0.8695 - lr: 0.0010
# Epoch 29/500
# 67/69 [============================>.] - ETA: 0s - loss: 0.0514 - custom_mean_iou: 0.9781
# Epoch 29: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0499 - custom_mean_iou: 0.9785 - val_loss: 0.2910 - val_custom_mean_iou: 0.8811 - lr: 0.0010
# Epoch 30/500
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0431 - custom_mean_iou: 0.9733
# Epoch 30: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0412 - custom_mean_iou: 0.9748 - val_loss: 0.3381 - val_custom_mean_iou: 0.8694 - lr: 0.0010
# Epoch 31/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0108 - custom_mean_iou: 0.9931
# Epoch 31: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0108 - custom_mean_iou: 0.9931 - val_loss: 0.1836 - val_custom_mean_iou: 0.8967 - lr: 0.0010
# Epoch 32/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0413 - custom_mean_iou: 0.9848
# Epoch 32: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 22ms/step - loss: 0.0413 - custom_mean_iou: 0.9848 - val_loss: 0.5080 - val_custom_mean_iou: 0.8292 - lr: 0.0010
# Epoch 33/500
# 69/69 [==============================] - ETA: 0s - loss: 0.0102 - custom_mean_iou: 0.9913
# Epoch 33: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0102 - custom_mean_iou: 0.9913 - val_loss: 0.2934 - val_custom_mean_iou: 0.8936 - lr: 1.0000e-04
# Epoch 34/500
# 69/69 [==============================] - ETA: 0s - loss: 4.5818e-04 - custom_mean_iou: 1.0000
# Epoch 34: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 2s 24ms/step - loss: 4.5818e-04 - custom_mean_iou: 1.0000 - val_loss: 0.2407 - val_custom_mean_iou: 0.9062 - lr: 1.0000e-04
# Epoch 35/500
# 69/69 [==============================] - ETA: 0s - loss: 5.0536e-05 - custom_mean_iou: 1.0000
# Epoch 35: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 2s 22ms/step - loss: 5.0536e-05 - custom_mean_iou: 1.0000 - val_loss: 0.2081 - val_custom_mean_iou: 0.9098 - lr: 1.0000e-04
# Epoch 36/500
# 68/69 [============================>.] - ETA: 0s - loss: 8.5153e-06 - custom_mean_iou: 1.0000
# Epoch 36: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 8.7591e-06 - custom_mean_iou: 1.0000 - val_loss: 0.2120 - val_custom_mean_iou: 0.8992 - lr: 1.0000e-04
# Epoch 37/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.4619e-05 - custom_mean_iou: 1.0000
# Epoch 37: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 1.4215e-05 - custom_mean_iou: 1.0000 - val_loss: 0.1993 - val_custom_mean_iou: 0.9029 - lr: 1.0000e-04
# Epoch 38/500
# 68/69 [============================>.] - ETA: 0s - loss: 4.7652e-06 - custom_mean_iou: 1.0000
# Epoch 38: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 4.8093e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1993 - val_custom_mean_iou: 0.9029 - lr: 1.0000e-04
# Epoch 39/500
# 69/69 [==============================] - ETA: 0s - loss: 6.0951e-06 - custom_mean_iou: 1.0000
# Epoch 39: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 21ms/step - loss: 6.0951e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1889 - val_custom_mean_iou: 0.9048 - lr: 1.0000e-04
# Epoch 40/500
# 66/69 [===========================>..] - ETA: 0s - loss: 9.1489e-06 - custom_mean_iou: 1.0000
# Epoch 40: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 8.7892e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1974 - val_custom_mean_iou: 0.9034 - lr: 1.0000e-04
# Epoch 41/500
# 69/69 [==============================] - ETA: 0s - loss: 2.3905e-06 - custom_mean_iou: 1.0000
# Epoch 41: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 18ms/step - loss: 2.3905e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1961 - val_custom_mean_iou: 0.9097 - lr: 1.0000e-04
# Epoch 42/500
# 66/69 [===========================>..] - ETA: 0s - loss: 5.1938e-06 - custom_mean_iou: 1.0000
# Epoch 42: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 5.0314e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1925 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 43/500
# 69/69 [==============================] - ETA: 0s - loss: 3.1108e-06 - custom_mean_iou: 1.0000
# Epoch 43: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 18ms/step - loss: 3.1108e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1934 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 44/500
# 68/69 [============================>.] - ETA: 0s - loss: 2.6094e-06 - custom_mean_iou: 1.0000
# Epoch 44: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 2.5810e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1940 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 45/500
# 69/69 [==============================] - ETA: 0s - loss: 2.0172e-06 - custom_mean_iou: 1.0000
# Epoch 45: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 2.0172e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1891 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 46/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.1071e-06 - custom_mean_iou: 1.0000
# Epoch 46: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 1.1899e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1902 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 47/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.6413e-06 - custom_mean_iou: 1.0000
# Epoch 47: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 17ms/step - loss: 1.6309e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1927 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 48/500
# 69/69 [==============================] - ETA: 0s - loss: 1.8718e-06 - custom_mean_iou: 1.0000
# Epoch 48: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 1.8718e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1909 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 49/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.5045e-06 - custom_mean_iou: 1.0000
# Epoch 49: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 1.7634e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1907 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 50/500
# 69/69 [==============================] - ETA: 0s - loss: 1.2568e-06 - custom_mean_iou: 1.0000
# Epoch 50: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 1.2568e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1908 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 51/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.4950e-06 - custom_mean_iou: 1.0000
# Epoch 51: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 19ms/step - loss: 1.5106e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1857 - val_custom_mean_iou: 0.9132 - lr: 1.0000e-04
# Epoch 52/500
# 69/69 [==============================] - ETA: 0s - loss: 1.6829e-06 - custom_mean_iou: 1.0000
# Epoch 52: val_custom_mean_iou did not improve from 0.91786
# 69/69 [==============================] - 1s 21ms/step - loss: 1.6829e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1848 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 53/500
# 68/69 [============================>.] - ETA: 0s - loss: 2.4219e-06 - custom_mean_iou: 1.0000
# Epoch 53: val_custom_mean_iou improved from 0.91786 to 0.91804, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_LWCNN_mIoU.h5
# 69/69 [==============================] - 2s 25ms/step - loss: 2.3875e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1820 - val_custom_mean_iou: 0.9180 - lr: 1.0000e-04
# Epoch 54/500
# 67/69 [============================>.] - ETA: 0s - loss: 8.1519e-07 - custom_mean_iou: 1.0000
# Epoch 54: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.0778e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1851 - val_custom_mean_iou: 0.9180 - lr: 1.0000e-04
# Epoch 55/500
# 69/69 [==============================] - ETA: 0s - loss: 2.8880e-05 - custom_mean_iou: 1.0000
# Epoch 55: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 18ms/step - loss: 2.8880e-05 - custom_mean_iou: 1.0000 - val_loss: 0.1874 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 56/500
# 69/69 [==============================] - ETA: 0s - loss: 9.2881e-07 - custom_mean_iou: 1.0000
# Epoch 56: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 9.2881e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1893 - val_custom_mean_iou: 0.9137 - lr: 1.0000e-04
# Epoch 57/500
# 66/69 [===========================>..] - ETA: 0s - loss: 3.8686e-06 - custom_mean_iou: 1.0000
# Epoch 57: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 3.7209e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1838 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 58/500
# 69/69 [==============================] - ETA: 0s - loss: 1.7886e-06 - custom_mean_iou: 1.0000
# Epoch 58: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 20ms/step - loss: 1.7886e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1872 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 59/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.6785e-06 - custom_mean_iou: 1.0000
# Epoch 59: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 28ms/step - loss: 1.6546e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1855 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 60/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.1417e-06 - custom_mean_iou: 1.0000
# Epoch 60: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 23ms/step - loss: 1.1137e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1841 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 61/500
# 67/69 [============================>.] - ETA: 0s - loss: 9.7177e-07 - custom_mean_iou: 1.0000
# Epoch 61: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 22ms/step - loss: 9.8093e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1856 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 62/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0166e-06 - custom_mean_iou: 1.0000
# Epoch 62: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 20ms/step - loss: 1.0166e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1858 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-04
# Epoch 63/500
# 69/69 [==============================] - ETA: 0s - loss: 1.1872e-06 - custom_mean_iou: 1.0000
# Epoch 63: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 3s 42ms/step - loss: 1.1872e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1855 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 64/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.1823e-06 - custom_mean_iou: 1.0000
# Epoch 64: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 30ms/step - loss: 1.1668e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1853 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 65/500
# 69/69 [==============================] - ETA: 0s - loss: 1.4280e-06 - custom_mean_iou: 1.0000
# Epoch 65: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 24ms/step - loss: 1.4280e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1848 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 66/500
# 69/69 [==============================] - ETA: 0s - loss: 1.7121e-06 - custom_mean_iou: 1.0000
# Epoch 66: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 25ms/step - loss: 1.7121e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 67/500
# 67/69 [============================>.] - ETA: 0s - loss: 9.4496e-07 - custom_mean_iou: 1.0000
# Epoch 67: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 9.5604e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1851 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 68/500
# 65/69 [===========================>..] - ETA: 0s - loss: 9.7062e-07 - custom_mean_iou: 1.0000
# Epoch 68: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 9.5857e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 69/500
# 66/69 [===========================>..] - ETA: 0s - loss: 7.9704e-07 - custom_mean_iou: 1.0000
# Epoch 69: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.0357e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1849 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 70/500
# 66/69 [===========================>..] - ETA: 0s - loss: 8.8244e-07 - custom_mean_iou: 1.0000
# Epoch 70: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.8646e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1855 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 71/500
# 67/69 [============================>.] - ETA: 0s - loss: 8.8484e-07 - custom_mean_iou: 1.0000
# Epoch 71: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 17ms/step - loss: 8.7724e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 72/500
# 68/69 [============================>.] - ETA: 0s - loss: 3.3473e-06 - custom_mean_iou: 1.0000
# Epoch 72: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 17ms/step - loss: 3.3004e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1850 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 73/500
# 69/69 [==============================] - ETA: 0s - loss: 1.2555e-06 - custom_mean_iou: 1.0000
# Epoch 73: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.2555e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 74/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.2173e-06 - custom_mean_iou: 1.0000
# Epoch 74: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 2s 28ms/step - loss: 1.2005e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1845 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 75/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.3791e-06 - custom_mean_iou: 1.0000
# Epoch 75: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 18ms/step - loss: 1.3592e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 76/500
# 69/69 [==============================] - ETA: 0s - loss: 1.5638e-06 - custom_mean_iou: 1.0000
# Epoch 76: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 21ms/step - loss: 1.5638e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1845 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 77/500
# 68/69 [============================>.] - ETA: 0s - loss: 9.8953e-07 - custom_mean_iou: 1.0000
# Epoch 77: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 18ms/step - loss: 9.7545e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1847 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 78/500
# 68/69 [============================>.] - ETA: 0s - loss: 9.8451e-07 - custom_mean_iou: 1.0000
# Epoch 78: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 9.7286e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 79/500
# 66/69 [===========================>..] - ETA: 0s - loss: 5.9048e-06 - custom_mean_iou: 1.0000
# Epoch 79: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 5.7031e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1834 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 80/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0118e-06 - custom_mean_iou: 1.0000
# Epoch 80: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.0118e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1837 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 81/500
# 69/69 [==============================] - ETA: 0s - loss: 9.0431e-07 - custom_mean_iou: 1.0000
# Epoch 81: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 9.0431e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1841 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 82/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.4234e-06 - custom_mean_iou: 1.0000
# Epoch 82: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.4584e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1840 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 83/500
# 66/69 [===========================>..] - ETA: 0s - loss: 8.4039e-07 - custom_mean_iou: 1.0000
# Epoch 83: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.7379e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1839 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 84/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0101e-06 - custom_mean_iou: 1.0000
# Epoch 84: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.0101e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1843 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 85/500
# 69/69 [==============================] - ETA: 0s - loss: 9.2436e-07 - custom_mean_iou: 1.0000
# Epoch 85: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 9.2436e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1839 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 86/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.8395e-06 - custom_mean_iou: 1.0000
# Epoch 86: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.7990e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1838 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 87/500
# 69/69 [==============================] - ETA: 0s - loss: 7.9766e-07 - custom_mean_iou: 1.0000
# Epoch 87: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 7.9766e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1836 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 88/500
# 69/69 [==============================] - ETA: 0s - loss: 7.0275e-07 - custom_mean_iou: 1.0000
# Epoch 88: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 7.0275e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1832 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 89/500
# 69/69 [==============================] - ETA: 0s - loss: 1.7352e-06 - custom_mean_iou: 1.0000
# Epoch 89: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 1.7352e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1830 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 90/500
# 66/69 [===========================>..] - ETA: 0s - loss: 7.0628e-07 - custom_mean_iou: 1.0000
# Epoch 90: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.8584e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1833 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 91/500
# 68/69 [============================>.] - ETA: 0s - loss: 2.4208e-06 - custom_mean_iou: 1.0000
# Epoch 91: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 2.4047e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1828 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 92/500
# 69/69 [==============================] - ETA: 0s - loss: 1.5638e-06 - custom_mean_iou: 1.0000
# Epoch 92: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.5638e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1829 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 93/500
# 67/69 [============================>.] - ETA: 0s - loss: 5.6733e-07 - custom_mean_iou: 1.0000
# Epoch 93: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.0325e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1832 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 94/500
# 69/69 [==============================] - ETA: 0s - loss: 1.1203e-06 - custom_mean_iou: 1.0000
# Epoch 94: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.1203e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1836 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 95/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.2030e-06 - custom_mean_iou: 1.0000
# Epoch 95: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.1680e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1837 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 96/500
# 69/69 [==============================] - ETA: 0s - loss: 9.2665e-07 - custom_mean_iou: 1.0000
# Epoch 96: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 9.2665e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1836 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 97/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.6117e-06 - custom_mean_iou: 1.0000
# Epoch 97: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.5938e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1834 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 98/500
# 69/69 [==============================] - ETA: 0s - loss: 9.4575e-07 - custom_mean_iou: 1.0000
# Epoch 98: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 9.4575e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1832 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 99/500
# 66/69 [===========================>..] - ETA: 0s - loss: 6.0046e-07 - custom_mean_iou: 1.0000
# Epoch 99: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.3515e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1832 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 100/500
# 69/69 [==============================] - ETA: 0s - loss: 8.4810e-07 - custom_mean_iou: 1.0000
# Epoch 100: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.4810e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1835 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 101/500
# 68/69 [============================>.] - ETA: 0s - loss: 8.2232e-07 - custom_mean_iou: 1.0000
# Epoch 101: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.2243e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1837 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 102/500
# 69/69 [==============================] - ETA: 0s - loss: 8.7166e-07 - custom_mean_iou: 1.0000
# Epoch 102: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.7166e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1836 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 103/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.1473e-06 - custom_mean_iou: 1.0000
# Epoch 103: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.5918e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1843 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 104/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.7363e-06 - custom_mean_iou: 1.0000
# Epoch 104: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 1.7518e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1839 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 105/500
# 69/69 [==============================] - ETA: 0s - loss: 8.0675e-07 - custom_mean_iou: 1.0000
# Epoch 105: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.0675e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1834 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 106/500
# 69/69 [==============================] - ETA: 0s - loss: 1.8247e-06 - custom_mean_iou: 1.0000
# Epoch 106: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.8247e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 107/500
# 69/69 [==============================] - ETA: 0s - loss: 6.1898e-06 - custom_mean_iou: 1.0000
# Epoch 107: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.1898e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1845 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 108/500
# 69/69 [==============================] - ETA: 0s - loss: 6.1881e-07 - custom_mean_iou: 1.0000
# Epoch 108: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 6.1881e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 109/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0122e-06 - custom_mean_iou: 1.0000
# Epoch 109: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.0122e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 110/500
# 69/69 [==============================] - ETA: 0s - loss: 5.5975e-07 - custom_mean_iou: 1.0000
# Epoch 110: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 5.5975e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1841 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 111/500
# 69/69 [==============================] - ETA: 0s - loss: 8.0320e-07 - custom_mean_iou: 1.0000
# Epoch 111: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.0320e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1844 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 112/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0807e-06 - custom_mean_iou: 1.0000
# Epoch 112: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.0807e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1843 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 113/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.2114e-06 - custom_mean_iou: 1.0000
# Epoch 113: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.2399e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1844 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 114/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.9079e-06 - custom_mean_iou: 1.0000
# Epoch 114: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.8637e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1847 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 115/500
# 69/69 [==============================] - ETA: 0s - loss: 8.7064e-07 - custom_mean_iou: 1.0000
# Epoch 115: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.7064e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1850 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 116/500
# 69/69 [==============================] - ETA: 0s - loss: 6.7681e-07 - custom_mean_iou: 1.0000
# Epoch 116: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 6.7681e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1845 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 117/500
# 66/69 [===========================>..] - ETA: 0s - loss: 8.4870e-07 - custom_mean_iou: 1.0000
# Epoch 117: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.1549e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1850 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 118/500
# 66/69 [===========================>..] - ETA: 0s - loss: 6.4586e-07 - custom_mean_iou: 1.0000
# Epoch 118: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.5797e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 119/500
# 66/69 [===========================>..] - ETA: 0s - loss: 7.2582e-07 - custom_mean_iou: 1.0000
# Epoch 119: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.1442e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1848 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 120/500
# 69/69 [==============================] - ETA: 0s - loss: 1.1374e-06 - custom_mean_iou: 1.0000
# Epoch 120: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.1374e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 121/500
# 66/69 [===========================>..] - ETA: 0s - loss: 9.6303e-07 - custom_mean_iou: 1.0000
# Epoch 121: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 9.5190e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1850 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 122/500
# 67/69 [============================>.] - ETA: 0s - loss: 6.7731e-07 - custom_mean_iou: 1.0000
# Epoch 122: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 7.1666e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 123/500
# 69/69 [==============================] - ETA: 0s - loss: 5.6946e-07 - custom_mean_iou: 1.0000
# Epoch 123: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 20ms/step - loss: 5.6946e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 124/500
# 69/69 [==============================] - ETA: 0s - loss: 8.0605e-07 - custom_mean_iou: 1.0000
# Epoch 124: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.0605e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 125/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0132e-06 - custom_mean_iou: 1.0000
# Epoch 125: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 1.0132e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1847 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 126/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.0495e-06 - custom_mean_iou: 1.0000
# Epoch 126: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 1.0702e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1851 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 127/500
# 68/69 [============================>.] - ETA: 0s - loss: 9.5935e-07 - custom_mean_iou: 1.0000
# Epoch 127: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 18ms/step - loss: 9.4572e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1859 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 128/500
# 68/69 [============================>.] - ETA: 0s - loss: 8.2905e-07 - custom_mean_iou: 1.0000
# Epoch 128: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 8.1734e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1857 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 129/500
# 69/69 [==============================] - ETA: 0s - loss: 8.5172e-07 - custom_mean_iou: 1.0000
# Epoch 129: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 18ms/step - loss: 8.5172e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 130/500
# 67/69 [============================>.] - ETA: 0s - loss: 5.7159e-07 - custom_mean_iou: 1.0000
# Epoch 130: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 20ms/step - loss: 5.5843e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1850 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 131/500
# 69/69 [==============================] - ETA: 0s - loss: 1.3578e-06 - custom_mean_iou: 1.0000
# Epoch 131: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.3578e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1849 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 132/500
# 69/69 [==============================] - ETA: 0s - loss: 1.3009e-06 - custom_mean_iou: 1.0000
# Epoch 132: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.3009e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 133/500
# 69/69 [==============================] - ETA: 0s - loss: 1.0649e-06 - custom_mean_iou: 1.0000
# Epoch 133: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.0649e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1856 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 134/500
# 66/69 [===========================>..] - ETA: 0s - loss: 7.5739e-07 - custom_mean_iou: 1.0000
# Epoch 134: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 7.4337e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1861 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 135/500
# 66/69 [===========================>..] - ETA: 0s - loss: 1.2403e-06 - custom_mean_iou: 1.0000
# Epoch 135: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.1890e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 136/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.0140e-06 - custom_mean_iou: 1.0000
# Epoch 136: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.0214e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 137/500
# 69/69 [==============================] - ETA: 0s - loss: 6.7019e-07 - custom_mean_iou: 1.0000
# Epoch 137: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.7019e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 138/500
# 69/69 [==============================] - ETA: 0s - loss: 1.4001e-06 - custom_mean_iou: 1.0000
# Epoch 138: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 1.4001e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1844 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 139/500
# 66/69 [===========================>..] - ETA: 0s - loss: 9.1101e-07 - custom_mean_iou: 1.0000
# Epoch 139: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.7513e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1841 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 140/500
# 67/69 [============================>.] - ETA: 0s - loss: 6.1550e-07 - custom_mean_iou: 1.0000
# Epoch 140: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 19ms/step - loss: 6.1383e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1848 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 141/500
# 66/69 [===========================>..] - ETA: 0s - loss: 9.8686e-07 - custom_mean_iou: 1.0000
# Epoch 141: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.0033e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1845 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 142/500
# 69/69 [==============================] - ETA: 0s - loss: 7.7622e-07 - custom_mean_iou: 1.0000
# Epoch 142: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 7.7622e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1844 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 143/500
# 66/69 [===========================>..] - ETA: 0s - loss: 5.8229e-07 - custom_mean_iou: 1.0000
# Epoch 143: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.0151e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 144/500
# 66/69 [===========================>..] - ETA: 0s - loss: 7.1878e-07 - custom_mean_iou: 1.0000
# Epoch 144: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.9629e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1849 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 145/500
# 69/69 [==============================] - ETA: 0s - loss: 8.7969e-07 - custom_mean_iou: 1.0000
# Epoch 145: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 8.7969e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1853 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 146/500
# 69/69 [==============================] - ETA: 0s - loss: 7.0997e-07 - custom_mean_iou: 1.0000
# Epoch 146: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 7.0997e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1852 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 147/500
# 67/69 [============================>.] - ETA: 0s - loss: 8.3723e-07 - custom_mean_iou: 1.0000
# Epoch 147: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 8.1490e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1848 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 148/500
# 69/69 [==============================] - ETA: 0s - loss: 7.2323e-07 - custom_mean_iou: 1.0000
# Epoch 148: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 7.2323e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1846 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 149/500
# 67/69 [============================>.] - ETA: 0s - loss: 1.2540e-06 - custom_mean_iou: 1.0000
# Epoch 149: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 1.2231e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1848 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 150/500
# 69/69 [==============================] - ETA: 0s - loss: 2.5885e-06 - custom_mean_iou: 1.0000
# Epoch 150: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 2.5885e-06 - custom_mean_iou: 1.0000 - val_loss: 0.1861 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 151/500
# 69/69 [==============================] - ETA: 0s - loss: 6.1234e-07 - custom_mean_iou: 1.0000
# Epoch 151: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 20ms/step - loss: 6.1234e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1853 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 152/500
# 67/69 [============================>.] - ETA: 0s - loss: 6.3169e-07 - custom_mean_iou: 1.0000
# Epoch 152: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 15ms/step - loss: 6.1845e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1859 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# Epoch 153/500
# 69/69 [==============================] - ETA: 0s - loss: 4.8328e-07 - custom_mean_iou: 1.0000
# Epoch 153: val_custom_mean_iou did not improve from 0.91804
# 69/69 [==============================] - 1s 16ms/step - loss: 4.8328e-07 - custom_mean_iou: 1.0000 - val_loss: 0.1854 - val_custom_mean_iou: 0.9167 - lr: 1.0000e-05
# CPU times: total: 7min 20s
# Wall time: 3min 18s

# %%
n_epochs = len(history.history['loss'])

acc = history.history['custom_mean_iou']
val_acc = history.history['val_custom_mean_iou']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(n_epochs) #change it based on epoch needed to finish building the model

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

labels, counts = np.unique(y, return_counts=True)
labels = labels -1
classes = ['Forest','Plantation','Agriculture', 'Shrubland', 'Bareland', 'Urban', 'Waterbody']

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)
score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred, labels=labels)

# plot the confusion matrix of LGB
dl_cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(dl_cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)


# Show all labels
ax.set(xticks=np.arange(dl_cm.shape[1]),
        yticks=np.arange(dl_cm.shape[0]),
        # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,
        title='Normalized Confusion Matrix',
        ylabel='True label',
        xlabel='Predicted label')

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
          rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
fmt = '.2f'
thresh = dl_cm.max() / 2.
for i in range(dl_cm.shape[0]):
    for j in range(dl_cm.shape[1]):
        ax.text(j, i, format(dl_cm[i, j], fmt),
                ha="center", va="center",
                color="white" if dl_cm[i, j] > thresh else "black")
fig.tight_layout()

# %%
# Calculate per-class IoU and mean IoU from raw confusion matrix
def calculate_iou_from_cm(cm):
    n_classes = cm.shape[0]
    class_iou = np.zeros(n_classes)
    
    for i in range(n_classes):
        # True positives: diagonal elements
        tp = cm[i, i]
        
        # False positives: sum of column i minus diagonal element
        fp = np.sum(cm[:, i]) - tp
        
        # False negatives: sum of row i minus diagonal element
        fn = np.sum(cm[i, :]) - tp
        
        # IoU calculation
        if tp + fp + fn == 0:
            class_iou[i] = 0
        else:
            class_iou[i] = tp / (tp + fp + fn)
    
    # Calculate mean IoU
    mean_iou = np.mean(class_iou)
    
    return class_iou, mean_iou

# Use your raw confusion matrix (before normalization)
class_iou, mean_iou = calculate_iou_from_cm(cm)  # 'cm' is your raw confusion matrix

print("Class IoU values:")
for i, class_name in enumerate(classes):
    print(f"{class_name}: {class_iou[i]:.4f}")
print(f"Mean IoU: {mean_iou:.4f}")

# %%
#Metric Precision, Recall, F-score support
from sklearn.metrics import precision_recall_fscore_support

y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)

macro_01 = precision_recall_fscore_support(y_test, y_pred, average='macro')
weighted_01 = precision_recall_fscore_support(y_test, y_pred, average='weighted')

print(macro_01)
print(weighted_01)

# %%
#Metric F1-score
from sklearn.metrics import f1_score

macro_02 = f1_score(y_test, y_pred, average='macro')
weighted_02 = f1_score(y_test, y_pred, average='weighted')

print(macro_02)
print(weighted_02)

# %%
# Print the precision and recall, among other metrics
from sklearn import metrics
from tensorflow.compat.v1.keras.models import load_model

# model = load_model('D:/Wiltang_2022/Paper_Data_Codes/Saved_Model/LC_Multivariate_Wonosobo_BiGRU_exp_ver01_metricmeasurement.h5')
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# y_test = y_test.argmax(axis=1)

print(metrics.classification_report(y_test, y_pred, digits=4))

# %%
import numpy as np
from sklearn.metrics import jaccard_score

y_pred_train = model.predict(X_train)
y_pred_train = y_pred_train.argmax(axis=1)
y_train = y_train.argmax(axis=1)

JS_test = jaccard_score(y_test, y_pred, average='macro')
JS_train = jaccard_score(y_train, y_pred_train, average='macro')
print(JS_test)
print(JS_train)

# %%
import numpy as np
from sklearn.metrics import jaccard_score

y_pred_train = model.predict(X_train)
y_pred_train = y_pred_train.argmax(axis=1)
# y_train = y_train.argmax(axis=1)

JS_test = jaccard_score(y_test, y_pred, average=None)
JS_train = jaccard_score(y_train, y_pred_train, average=None)
print(JS_test)
print(JS_train)

# %%
from sklearn.metrics import cohen_kappa_score

model_kappa = cohen_kappa_score(y_pred, y_test)
print(model_kappa)

# %%
# data_test = {'ytest': y_test,
#         'ytest_pred': y_pred}

# data_train = {'ytest': y_train,
#         'ytest_pred': y_pred_train}

# df_test = pd.DataFrame(data_test)
# df_train = pd.DataFrame(data_train)

# df_test.to_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/df_test.csv')
# df_train.to_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/df_train.csv')

# %%
# from tensorflow.keras.utils import plot_model
# import pydot
# import pydotplus
# from pydotplus import graphviz

# plot_model(model, to_file='D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model/model3_plot.png', 
#            show_shapes=True, show_layer_names=True)

# %%
#https://doi.org/10.1080/15481603.2023.2271246
