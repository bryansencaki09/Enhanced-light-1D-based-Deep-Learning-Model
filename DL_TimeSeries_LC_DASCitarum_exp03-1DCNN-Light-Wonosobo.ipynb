# %%
import tensorflow as tf
tf.__version__
tf.keras.backend.clear_session()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
# import keras.backend as K
# from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.backend import sigmoid
from tensorflow.keras.models import Sequential, Model
# from tensorflow.keras.regularizers import l1,l2, l1_l2
# from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Layer, Permute, multiply
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Conv1D, Dropout, Dense, BatchNormalization, AveragePooling1D, ReLU, LayerNormalization
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Lambda, Reshape, Flatten, SeparableConv1D, Activation, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Add, MaxPooling1D, MultiHeadAttention, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.compat.v1.keras.models import load_model
# from tensorflow.compat.v1.keras.layers import CuDNNGRU
import sklearn
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight

# %%
data_cbi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/CBI_final.csv')
data_bsi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/BSI_final.csv')
data_evi2= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/EVI2_final.csv')
data_mndwi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/MNDWI_final.csv')
data_msavi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/MSAVI_final.csv')
data_nbr= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/NBR_final.csv')
data_ndvi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/NDVI_final.csv')

# %%
#interpolate NaN for each row
# data_b2 = data_b2.apply(pd.to_numeric, errors='coerce')
# data_b3 = data_b3.apply(pd.to_numeric, errors='coerce')
# data_b4 = data_b4.apply(pd.to_numeric, errors='coerce')
# data_b5 = data_b5.apply(pd.to_numeric, errors='coerce')
# data_b6 = data_b6.apply(pd.to_numeric, errors='coerce')
# data_b7 = data_b7.apply(pd.to_numeric, errors='coerce')
# data_b8 = data_b8.apply(pd.to_numeric, errors='coerce')
# data_b8A = data_b8A.apply(pd.to_numeric, errors='coerce')
# data_b11 = data_b11.apply(pd.to_numeric, errors='coerce')
# data_b12 = data_b12.apply(pd.to_numeric, errors='coerce')

data_cbi_ = data_cbi.values
data_bsi_ = data_bsi.values
data_evi2_ = data_evi2.values
data_mndwi_ = data_mndwi.values
data_msavi_ = data_msavi.values
data_nbr_ = data_nbr.values
data_ndvi_ = data_ndvi.values

cbi_pd = pd.DataFrame(data_cbi_)
bsi_pd = pd.DataFrame(data_bsi_)
evi2_pd = pd.DataFrame(data_evi2_)
mndwi_pd = pd.DataFrame(data_mndwi_)
msavi_pd = pd.DataFrame(data_msavi_)
nbr_pd = pd.DataFrame(data_nbr_)
ndvi_pd = pd.DataFrame(data_ndvi_)

cbi_pd = cbi_pd.iloc[:,3:42].astype(float)
bsi_pd = bsi_pd.iloc[:,3:42].astype(float)
evi2_pd  = evi2_pd.iloc[:,3:42].astype(float)
mndwi_pd  = mndwi_pd.iloc[:,3:42].astype(float)
msavi_pd = msavi_pd.iloc[:,3:42].astype(float)
nbr_pd  = nbr_pd.iloc[:,3:42].astype(float)
ndvi_pd  = ndvi_pd.iloc[:,3:42].astype(float)

# data_b2_int = data_b2.interpolate(method='linear', limit_direction='both', axis=1)
# data_b3_int = data_b3.interpolate(method='linear', limit_direction='both', axis=1)
# data_b4_int = data_b4.interpolate(method='linear', limit_direction='both', axis=1)
# data_b5_int = data_b5.interpolate(method='linear', limit_direction='both', axis=1)
# data_b6_int = data_b6.interpolate(method='linear', limit_direction='both', axis=1)
# data_b7_int = data_b7.interpolate(method='linear', limit_direction='both', axis=1)
# data_b8_int = data_b8.interpolate(method='linear', limit_direction='both', axis=1)
# data_b8A_int = data_b8A.interpolate(method='linear', limit_direction='both', axis=1)
# data_b11_int = data_b11.interpolate(method='linear', limit_direction='both', axis=1)
# data_b12_int = data_b12.interpolate(method='linear', limit_direction='both', axis=1)

data_cbi_int = cbi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_bsi_int = bsi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_evi2_int = evi2_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_mndwi_int = mndwi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_msavi_int = msavi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_nbr_int = nbr_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_ndvi_int = ndvi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)

# print('Number of nan for B2 after:', data_b2_int.isnull().sum().sum())
# print('Number of nan for B3 after:', data_b3_int.isnull().sum().sum())
# print('Number of nan for B4 after:', data_b4_int.isnull().sum().sum())
# print('Number of nan for B5 after:', data_b5_int.isnull().sum().sum())
# print('Number of nan for B6 after:', data_b6_int.isnull().sum().sum())
# print('Number of nan for B7 after:', data_b7_int.isnull().sum().sum())
# print('Number of nan for B8 after:', data_b8_int.isnull().sum().sum())
# print('Number of nan for B8A after:', data_b8A_int.isnull().sum().sum())
# print('Number of nan for B11 after:', data_b11_int.isnull().sum().sum())
# print('Number of nan for B12 after:', data_b12_int.isnull().sum().sum())

print('Number of nan for CBI after:', np.count_nonzero(np.isnan(data_cbi_int)))
print('Number of nan for BSI after:', np.count_nonzero(np.isnan(data_bsi_int)))
print('Number of nan for EVI2 after:', np.count_nonzero(np.isnan(data_evi2_int)))
print('Number of nan for MNDWI after:', data_mndwi_int.isnull().sum().sum())
print('Number of nan for MSAVI after:', data_msavi_int.isnull().sum().sum())
print('Number of nan for NBR after:', data_nbr_int.isnull().sum().sum())
print('Number of nan for NDVI after:', data_ndvi_int.isnull().sum().sum())
# Out:
# Number of nan for CBI after: 0
# Number of nan for BSI after: 0
# Number of nan for EVI2 after: 0
# Number of nan for MNDWI after: 0
# Number of nan for MSAVI after: 0
# Number of nan for NBR after: 0
# Number of nan for NDVI after: 0

# %%
comb_all = pd.concat([data_cbi_int, data_bsi_int, data_evi2_int,
                      data_mndwi_int, data_msavi_int, 
                      data_nbr_int, data_ndvi_int], axis =0, ignore_index=True)

# %%
# comb_all_lc = pd.concat([data_cbi.iloc[:,0:3], data_bsi.iloc[:,0:3], data_evi2.iloc[:,0:3],
#                             data_mndwi.iloc[:,0:3], data_msavi.iloc[:,0:3],
#                             data_nbr.iloc[:,0:3], data_ndvi.iloc[:,0:3]], axis =0, ignore_index=True)

# %%
# print(comb_all_lc.Class.value_counts())

# %%
y = data_cbi.iloc[:,2]
y = np.asarray(y).astype(np.float32)
y_cat = to_categorical(y)
y_cat = y_cat[:,1:8] # num_class + 1

# %%
# print(y.shape)

# %%
# print(y_cat)
# print(y_cat.shape)

# %%
# print(np.unique(y))

# %%
class_weights = compute_class_weight(class_weight = "balanced",
                                      classes = np.unique(y), y=y)
class_weights = dict(enumerate(class_weights))
# class_weights = dict(zip(np.unique(train_classes), class_weights))
print(class_weights)
# Out:
# {0: 1.2355889724310778, 1: 0.985014985014985, 2: 0.4977284199899041, 3: 2.9969604863221884, 4: 1.5916061339790153, 5: 0.8072042570609906, 6: 1.0357142857142858}

# %%
# comb_b2 = comb_all.iloc[0:1939:,3:31]
# comb_b3 = comb_all.iloc[1939:3878:,3:31]
# comb_b4 = comb_all.iloc[3878:5817:,3:31]
# comb_b5 = comb_all.iloc[5817:7756:,3:31]
# comb_b6 = comb_all.iloc[7756:9695:,3:31]
# comb_b7 = comb_all.iloc[9695:11634:,3:31]
# comb_b8 = comb_all.iloc[11634:13573:,3:31]
# comb_b8A = comb_all.iloc[13573:15512:,3:31]
# comb_b11 = comb_all.iloc[15512:17451:,3:31]
# comb_b12 = comb_all.iloc[17451:19390:,3:31]

comb_cbi = comb_all.iloc[0:1972:,:]
comb_bsi = comb_all.iloc[1972:3944:,:]
comb_evi2 = comb_all.iloc[3944:5916:,:]
comb_mndwi = comb_all.iloc[5916:7888:,:]
comb_msavi = comb_all.iloc[7888:9860:,:]
comb_nbr = comb_all.iloc[9860:11832:,:]
comb_ndvi = comb_all.iloc[11832:13804:,:]

# comb_b2= np.asarray(comb_b2).astype(np.float32)
# comb_b3= np.asarray(comb_b3).astype(np.float32)
# comb_b4= np.asarray(comb_b4).astype(np.float32)
# comb_b5= np.asarray(comb_b5).astype(np.float32)
# comb_b6= np.asarray(comb_b6).astype(np.float32)
# comb_b7= np.asarray(comb_b7).astype(np.float32)
# comb_b8= np.asarray(comb_b8).astype(np.float32)
# comb_b8A= np.asarray(comb_b8A).astype(np.float32)
# comb_b11= np.asarray(comb_b11).astype(np.float32)
# comb_b12= np.asarray(comb_b12).astype(np.float32)

comb_cbi= np.asarray(comb_cbi).astype(np.float64)
comb_bsi= np.asarray(comb_bsi).astype(np.float64)
comb_evi2= np.asarray(comb_evi2).astype(np.float64)
comb_mndwi= np.asarray(comb_mndwi).astype(np.float64)
comb_msavi= np.asarray(comb_msavi).astype(np.float64)
comb_nbr= np.asarray(comb_nbr).astype(np.float64)
comb_ndvi= np.asarray(comb_ndvi).astype(np.float64)

# %%
comb_stack = np.stack((comb_cbi, comb_bsi, comb_evi2,
                       comb_mndwi, comb_msavi, comb_nbr, 
                       comb_ndvi), axis=1)

# comb_stack = np.stack((comb_cbi, comb_bsi, comb_evi2), axis=1)
# print(comb_stack.shape)

comb_stack_reshape = comb_stack.reshape(comb_stack.shape[0], comb_stack.shape[2], comb_stack.shape[1])
print(comb_stack_reshape.shape)

X_train, X_test, y_train, y_test = train_test_split(comb_stack_reshape , y_cat, test_size=0.30, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1972, 39, 7)
# (1380, 39, 7) (1380, 7) (592, 39, 7) (592, 7)

# %%
# print(comb_cbi.shape)

# %%
# stack_ver = np.hstack((vert_cbi, vert_bsi, vert_evi2,
#                        vert_mndwi, vert_msavi, vert_nbr, 
#                        vert_ndvi))
# print(stack_ver.shape)

# %%
# import seaborn as sns 

# x = ['CBI','BSI','EVI2', 'MNDWI', 'MSAVI', 'NBR', 'NDVI']
# # enumerate label
# for i in enumerate(x):
#     print(i)

# # plot correlation matrix
# rf_pd = pd.DataFrame(data=stack_ver, columns=list(x))
# matrix = np.triu(rf_pd.corr())
# plt.figure(figsize=(12,8))
# sns.heatmap(rf_pd.corr(), annot=True, mask=matrix)

# %%
num_classes = len(np.unique(y))
input_shape=(X_train.shape[1], X_train.shape[2])
print(num_classes)
print(input_shape)
# Out:
# 7
# (39, 7)

# %%
def swish(x, beta = 1):
    return (x * sigmoid(beta * x))

tf.keras.utils.get_custom_objects().update({'swish': swish})

# %%
def ReshapeLayer(x):
    shape = x.shape
    # 1 possibility: H,W*channel
    reshape = Reshape((shape[1],shape[2]))(x)
    # 2 possibility: W,H*channel
    # transpose = Permute((2,1,3))(x)
    # reshape = Reshape((shape[1],shape[2]*shape[3]))(transpose)
    return reshape

# %%
# def attention_block(inputs, output_shape):
#     a = Permute((2, 1))(inputs)
#     a = Dense(output_shape, activation='softmax')(a)
#     a_probs = Permute((2, 1))(a)
#     output_attention_mul = multiply([inputs, a_probs])
#     return output_attention_mul

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Metric

class CustomMeanIoU(Metric):
    def __init__(self, num_classes, name='custom_mean_iou', **kwargs):
        super(CustomMeanIoU, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.confusion_matrix = self.add_weight(
            'confusion_matrix',
            shape=(num_classes, num_classes),
            initializer='zeros',
            dtype=tf.float32)
            
    def update_state(self, y_true, y_pred, sample_weight=None):
        # First, ensure y_pred is class indices (argmax) and cast to int32
        if len(tf.shape(y_pred)) > 1 and tf.shape(y_pred)[-1] > 1:
            y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
        else:
            # If not one-hot, ensure it's still int32
            y_pred = tf.cast(y_pred, tf.int32)
        
        # Then ensure y_true is the same format (class indices as int32)
        if len(tf.shape(y_true)) > 1 and tf.shape(y_true)[-1] > 1:
            y_true = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)
        else:
            # If not one-hot, ensure it's still int32
            y_true = tf.cast(y_true, tf.int32)
            
        # Convert to 1D tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])
        
        # Calculate confusion matrix
        cm_update = tf.math.confusion_matrix(
            y_true, y_pred, self.num_classes, 
            dtype=tf.float32)
        
        # Update the total confusion matrix
        self.confusion_matrix.assign_add(cm_update)
        
    def result(self):
        cm = self.confusion_matrix
        
        # Extract per-class TP, FP, FN
        tp = tf.linalg.diag_part(cm)
        sum_over_row = tf.reduce_sum(cm, axis=1)
        sum_over_col = tf.reduce_sum(cm, axis=0)
        fp = sum_over_col - tp
        fn = sum_over_row - tp
        
        # Calculate IoU per class
        denominator = tp + fp + fn
        
        # Avoid division by zero
        iou = tf.math.divide_no_nan(tp, denominator)
        
        # Calculate mean IoU (average over classes)
        valid_classes = tf.cast(denominator > 0, tf.float32)
        num_valid = tf.reduce_sum(valid_classes)
        
        # Return mean IoU
        return tf.math.divide_no_nan(tf.reduce_sum(iou), num_valid)
        
    def reset_state(self):
        # Reset the confusion matrix at the start of each epoch
        self.confusion_matrix.assign(tf.zeros((self.num_classes, self.num_classes)))

    def get_config(self):
        config = super(CustomMeanIoU, self).get_config()
        config.update({"num_classes": self.num_classes})
        return config

# %%
# %%time

def make_model(input_shape):
    input_layer = Input(input_shape)
    
    x0 = Conv1D(64, 3, strides=1, activation="swish", padding = 'same')(input_layer)
    x0 = Conv1D(64, 3, strides=1, activation="swish", padding = 'same')(x0) #add
    x0 = LayerNormalization()(x0)
    x0 = Dropout(0.5)(x0)
    
    x01 = Conv1D(64, 3, activation="swish", padding = 'same')(x0)
    x01 = Conv1D(64, 3, activation="swish", padding = 'same')(x01)
    x01 = LayerNormalization()(x01)
    x01 = Dropout(0.5)(x01)
    
    x02 = Conv1D(64, 3, activation="swish", padding = 'same')(x01)
    x02 = Conv1D(64, 3, activation="swish", padding = 'same')(x02)
    x02 = LayerNormalization()(x02)
    x02 = Dropout(0.5)(x02)
    
    add_ = tf.keras.layers.add([x0, x02])

    
    xfin = Lambda(ReshapeLayer)(add_)
    xfin = Bidirectional(GRU(128, activation='tanh', return_sequences=False))(xfin)
    xfin = Dense(64, activation="swish")(xfin)
    xfin = Dense(64, activation="swish")(xfin)
    xfin = LayerNormalization()(xfin)
    xfin = Dropout(0.75)(xfin)

    output_layer = Dense(num_classes, activation="softmax")(xfin)

    return Model(inputs=input_layer, outputs=output_layer)

model = make_model(input_shape= input_shape)
model.summary()
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                    optimizer=optimizers.Adam(learning_rate=0.001), 
                    metrics=[CustomMeanIoU(num_classes=7)])

checkpoint = ModelCheckpoint(filepath='D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model/LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5',
                              monitor='val_custom_mean_iou',save_best_only=True,verbose=1,mode='max')
early_stop = EarlyStopping(monitor='val_custom_mean_iou',patience=100,restore_best_weights=True,mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_custom_mean_iou', factor=0.1,patience=30, min_lr=0.00001)

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size =20,
                    epochs=500, callbacks = [checkpoint, early_stop, reduce_lr], 
                    class_weight=class_weights)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 39, 7)]              0         []
#
#  conv1d (Conv1D)             (None, 39, 64)               1408      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 39, 64)               12352     ['conv1d[0][0]']
#
#  layer_normalization (Layer  (None, 39, 64)               128       ['conv1d_1[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 39, 64)               0         ['layer_normalization[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 39, 64)               12352     ['dropout[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 39, 64)               12352     ['conv1d_2[0][0]']
#
#  layer_normalization_1 (Lay  (None, 39, 64)               128       ['conv1d_3[0][0]']
#  erNormalization)
#
#  dropout_1 (Dropout)         (None, 39, 64)               0         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 39, 64)               12352     ['dropout_1[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 39, 64)               12352     ['conv1d_4[0][0]']
#
#  layer_normalization_2 (Lay  (None, 39, 64)               128       ['conv1d_5[0][0]']
#  erNormalization)
#
#  dropout_2 (Dropout)         (None, 39, 64)               0         ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 39, 64)               0         ['dropout[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  lambda (Lambda)             (None, 39, 64)               0         ['add[0][0]']
#
#  bidirectional (Bidirection  (None, 256)                  148992    ['lambda[0][0]']
#  al)
#
#  dense (Dense)               (None, 64)                   16448     ['bidirectional[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   4160      ['dense[0][0]']
#
#  layer_normalization_3 (Lay  (None, 64)                   128       ['dense_1[0][0]']
#  erNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                   0         ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 7)                    455       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 233735 (913.03 KB)
# Trainable params: 233735 (913.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/500
# 69/69 [==============================] - ETA: 0s - loss: 2.6770 - custom_mean_iou: 0.1641
# Epoch 1: val_custom_mean_iou improved from -inf to 0.30108, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# D:\anaconda\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/69 [==============================] - 12s 81ms/step - loss: 2.6770 - custom_mean_iou: 0.1641 - val_loss: 1.2887 - val_custom_mean_iou: 0.3011 - lr: 0.0010
# Epoch 2/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.8409 - custom_mean_iou: 0.2513
# Epoch 2: val_custom_mean_iou did not improve from 0.30108
# 69/69 [==============================] - 3s 48ms/step - loss: 1.8375 - custom_mean_iou: 0.2524 - val_loss: 1.1588 - val_custom_mean_iou: 0.2945 - lr: 0.0010
# Epoch 3/500
# 69/69 [==============================] - ETA: 0s - loss: 1.5916 - custom_mean_iou: 0.2834
# Epoch 3: val_custom_mean_iou improved from 0.30108 to 0.46328, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 48ms/step - loss: 1.5916 - custom_mean_iou: 0.2834 - val_loss: 0.9992 - val_custom_mean_iou: 0.4633 - lr: 0.0010
# Epoch 4/500
# 69/69 [==============================] - ETA: 0s - loss: 1.3712 - custom_mean_iou: 0.3234
# Epoch 4: val_custom_mean_iou improved from 0.46328 to 0.55164, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 4s 56ms/step - loss: 1.3712 - custom_mean_iou: 0.3234 - val_loss: 0.9461 - val_custom_mean_iou: 0.5516 - lr: 0.0010
# Epoch 5/500
# 69/69 [==============================] - ETA: 0s - loss: 1.2614 - custom_mean_iou: 0.3421
# Epoch 5: val_custom_mean_iou improved from 0.55164 to 0.58676, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 51ms/step - loss: 1.2614 - custom_mean_iou: 0.3421 - val_loss: 0.8879 - val_custom_mean_iou: 0.5868 - lr: 0.0010
# Epoch 6/500
# 69/69 [==============================] - ETA: 0s - loss: 1.1344 - custom_mean_iou: 0.4057
# Epoch 6: val_custom_mean_iou did not improve from 0.58676
# 69/69 [==============================] - 3s 49ms/step - loss: 1.1344 - custom_mean_iou: 0.4057 - val_loss: 0.9093 - val_custom_mean_iou: 0.4456 - lr: 0.0010
# Epoch 7/500
# 69/69 [==============================] - ETA: 0s - loss: 1.1197 - custom_mean_iou: 0.4027
# Epoch 7: val_custom_mean_iou did not improve from 0.58676
# 69/69 [==============================] - 3s 45ms/step - loss: 1.1197 - custom_mean_iou: 0.4027 - val_loss: 0.7541 - val_custom_mean_iou: 0.5562 - lr: 0.0010
# Epoch 8/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.0164 - custom_mean_iou: 0.4531
# Epoch 8: val_custom_mean_iou improved from 0.58676 to 0.61772, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 49ms/step - loss: 1.0100 - custom_mean_iou: 0.4552 - val_loss: 0.6158 - val_custom_mean_iou: 0.6177 - lr: 0.0010
# Epoch 9/500
# 69/69 [==============================] - ETA: 0s - loss: 0.9740 - custom_mean_iou: 0.4785
# Epoch 9: val_custom_mean_iou improved from 0.61772 to 0.62199, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 48ms/step - loss: 0.9740 - custom_mean_iou: 0.4785 - val_loss: 0.6608 - val_custom_mean_iou: 0.6220 - lr: 0.0010
# Epoch 10/500
# 69/69 [==============================] - ETA: 0s - loss: 0.9250 - custom_mean_iou: 0.4934
# Epoch 10: val_custom_mean_iou did not improve from 0.62199
# 69/69 [==============================] - 3s 45ms/step - loss: 0.9250 - custom_mean_iou: 0.4934 - val_loss: 0.6775 - val_custom_mean_iou: 0.5515 - lr: 0.0010
# Epoch 11/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.8849 - custom_mean_iou: 0.5167
# Epoch 11: val_custom_mean_iou did not improve from 0.62199
# 69/69 [==============================] - 3s 46ms/step - loss: 0.8821 - custom_mean_iou: 0.5181 - val_loss: 0.6805 - val_custom_mean_iou: 0.5821 - lr: 0.0010
# Epoch 12/500
# 69/69 [==============================] - ETA: 0s - loss: 0.7596 - custom_mean_iou: 0.5895
# Epoch 12: val_custom_mean_iou did not improve from 0.62199
# 69/69 [==============================] - 3s 45ms/step - loss: 0.7596 - custom_mean_iou: 0.5895 - val_loss: 0.6282 - val_custom_mean_iou: 0.5879 - lr: 0.0010
# Epoch 13/500
# 69/69 [==============================] - ETA: 0s - loss: 0.8046 - custom_mean_iou: 0.5546
# Epoch 13: val_custom_mean_iou improved from 0.62199 to 0.67232, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 48ms/step - loss: 0.8046 - custom_mean_iou: 0.5546 - val_loss: 0.5194 - val_custom_mean_iou: 0.6723 - lr: 0.0010
# Epoch 14/500
# 69/69 [==============================] - ETA: 0s - loss: 0.7544 - custom_mean_iou: 0.5703
# Epoch 14: val_custom_mean_iou improved from 0.67232 to 0.71308, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 48ms/step - loss: 0.7544 - custom_mean_iou: 0.5703 - val_loss: 0.4274 - val_custom_mean_iou: 0.7131 - lr: 0.0010
# Epoch 15/500
# 69/69 [==============================] - ETA: 0s - loss: 0.7250 - custom_mean_iou: 0.5862
# Epoch 15: val_custom_mean_iou did not improve from 0.71308
# 69/69 [==============================] - 4s 63ms/step - loss: 0.7250 - custom_mean_iou: 0.5862 - val_loss: 0.5399 - val_custom_mean_iou: 0.6400 - lr: 0.0010
# Epoch 16/500
# 69/69 [==============================] - ETA: 0s - loss: 0.7699 - custom_mean_iou: 0.5522
# Epoch 16: val_custom_mean_iou did not improve from 0.71308
# 69/69 [==============================] - 4s 62ms/step - loss: 0.7699 - custom_mean_iou: 0.5522 - val_loss: 0.4600 - val_custom_mean_iou: 0.6722 - lr: 0.0010
# Epoch 17/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.6122 - custom_mean_iou: 0.6380
# Epoch 17: val_custom_mean_iou did not improve from 0.71308
# 69/69 [==============================] - 3s 46ms/step - loss: 0.6192 - custom_mean_iou: 0.6329 - val_loss: 0.5392 - val_custom_mean_iou: 0.6361 - lr: 0.0010
# Epoch 18/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.6953 - custom_mean_iou: 0.6048
# Epoch 18: val_custom_mean_iou did not improve from 0.71308
# 69/69 [==============================] - 3s 46ms/step - loss: 0.6934 - custom_mean_iou: 0.6048 - val_loss: 0.4326 - val_custom_mean_iou: 0.6901 - lr: 0.0010
# Epoch 19/500
# 69/69 [==============================] - ETA: 0s - loss: 0.6032 - custom_mean_iou: 0.6334
# Epoch 19: val_custom_mean_iou did not improve from 0.71308
# 69/69 [==============================] - 3s 46ms/step - loss: 0.6032 - custom_mean_iou: 0.6334 - val_loss: 0.4981 - val_custom_mean_iou: 0.6868 - lr: 0.0010
# Epoch 20/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5407 - custom_mean_iou: 0.6819
# Epoch 20: val_custom_mean_iou did not improve from 0.71308
# 69/69 [==============================] - 3s 46ms/step - loss: 0.5407 - custom_mean_iou: 0.6819 - val_loss: 0.4863 - val_custom_mean_iou: 0.6963 - lr: 0.0010
# Epoch 21/500
# 69/69 [==============================] - ETA: 0s - loss: 0.6465 - custom_mean_iou: 0.6211
# Epoch 21: val_custom_mean_iou improved from 0.71308 to 0.72375, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 50ms/step - loss: 0.6465 - custom_mean_iou: 0.6211 - val_loss: 0.4207 - val_custom_mean_iou: 0.7238 - lr: 0.0010
# Epoch 22/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.5154 - custom_mean_iou: 0.6853
# Epoch 22: val_custom_mean_iou improved from 0.72375 to 0.76288, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 4s 53ms/step - loss: 0.5107 - custom_mean_iou: 0.6872 - val_loss: 0.3283 - val_custom_mean_iou: 0.7629 - lr: 0.0010
# Epoch 23/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5244 - custom_mean_iou: 0.6944
# Epoch 23: val_custom_mean_iou did not improve from 0.76288
# 69/69 [==============================] - 3s 43ms/step - loss: 0.5244 - custom_mean_iou: 0.6944 - val_loss: 0.5062 - val_custom_mean_iou: 0.6501 - lr: 0.0010
# Epoch 24/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4996 - custom_mean_iou: 0.6998
# Epoch 24: val_custom_mean_iou did not improve from 0.76288
# 69/69 [==============================] - 3s 45ms/step - loss: 0.4996 - custom_mean_iou: 0.6998 - val_loss: 0.4217 - val_custom_mean_iou: 0.7172 - lr: 0.0010
# Epoch 25/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5190 - custom_mean_iou: 0.6945
# Epoch 25: val_custom_mean_iou did not improve from 0.76288
# 69/69 [==============================] - 3s 45ms/step - loss: 0.5190 - custom_mean_iou: 0.6945 - val_loss: 0.3807 - val_custom_mean_iou: 0.7393 - lr: 0.0010
# Epoch 26/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.4182 - custom_mean_iou: 0.7321
# Epoch 26: val_custom_mean_iou did not improve from 0.76288
# 69/69 [==============================] - 3s 44ms/step - loss: 0.4191 - custom_mean_iou: 0.7317 - val_loss: 0.3690 - val_custom_mean_iou: 0.7425 - lr: 0.0010
# Epoch 27/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.4165 - custom_mean_iou: 0.7603
# Epoch 27: val_custom_mean_iou did not improve from 0.76288
# 69/69 [==============================] - 3s 44ms/step - loss: 0.4146 - custom_mean_iou: 0.7614 - val_loss: 0.3606 - val_custom_mean_iou: 0.7494 - lr: 0.0010
# Epoch 28/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.4360 - custom_mean_iou: 0.7363
# Epoch 28: val_custom_mean_iou improved from 0.76288 to 0.77696, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 49ms/step - loss: 0.4311 - custom_mean_iou: 0.7377 - val_loss: 0.3112 - val_custom_mean_iou: 0.7770 - lr: 0.0010
# Epoch 29/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4137 - custom_mean_iou: 0.7500
# Epoch 29: val_custom_mean_iou did not improve from 0.77696
# 69/69 [==============================] - 3s 43ms/step - loss: 0.4137 - custom_mean_iou: 0.7500 - val_loss: 0.3487 - val_custom_mean_iou: 0.7638 - lr: 0.0010
# Epoch 30/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.3994 - custom_mean_iou: 0.7749
# Epoch 30: val_custom_mean_iou did not improve from 0.77696
# 69/69 [==============================] - 3s 44ms/step - loss: 0.4017 - custom_mean_iou: 0.7703 - val_loss: 0.3731 - val_custom_mean_iou: 0.7364 - lr: 0.0010
# Epoch 31/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4091 - custom_mean_iou: 0.7477
# Epoch 31: val_custom_mean_iou improved from 0.77696 to 0.80989, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 48ms/step - loss: 0.4091 - custom_mean_iou: 0.7477 - val_loss: 0.2626 - val_custom_mean_iou: 0.8099 - lr: 0.0010
# Epoch 32/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3495 - custom_mean_iou: 0.7757
# Epoch 32: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 44ms/step - loss: 0.3495 - custom_mean_iou: 0.7757 - val_loss: 0.3253 - val_custom_mean_iou: 0.7911 - lr: 0.0010
# Epoch 33/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.3400 - custom_mean_iou: 0.8023
# Epoch 33: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.3398 - custom_mean_iou: 0.8036 - val_loss: 0.2984 - val_custom_mean_iou: 0.8027 - lr: 1.0000e-04
# Epoch 34/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3184 - custom_mean_iou: 0.8027
# Epoch 34: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.3184 - custom_mean_iou: 0.8027 - val_loss: 0.3190 - val_custom_mean_iou: 0.7945 - lr: 1.0000e-04
# Epoch 35/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2803 - custom_mean_iou: 0.8245
# Epoch 35: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2803 - custom_mean_iou: 0.8245 - val_loss: 0.3114 - val_custom_mean_iou: 0.7918 - lr: 1.0000e-04
# Epoch 36/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2904 - custom_mean_iou: 0.8128
# Epoch 36: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2897 - custom_mean_iou: 0.8132 - val_loss: 0.3203 - val_custom_mean_iou: 0.7895 - lr: 1.0000e-04
# Epoch 37/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2685 - custom_mean_iou: 0.8366
# Epoch 37: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2685 - custom_mean_iou: 0.8366 - val_loss: 0.3143 - val_custom_mean_iou: 0.7949 - lr: 1.0000e-04
# Epoch 38/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2699 - custom_mean_iou: 0.8376
# Epoch 38: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2724 - custom_mean_iou: 0.8353 - val_loss: 0.3045 - val_custom_mean_iou: 0.7903 - lr: 1.0000e-04
# Epoch 39/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2837 - custom_mean_iou: 0.8172
# Epoch 39: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2837 - custom_mean_iou: 0.8172 - val_loss: 0.3008 - val_custom_mean_iou: 0.8030 - lr: 1.0000e-04
# Epoch 40/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2548 - custom_mean_iou: 0.8354
# Epoch 40: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2548 - custom_mean_iou: 0.8354 - val_loss: 0.3131 - val_custom_mean_iou: 0.8066 - lr: 1.0000e-04
# Epoch 41/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2692 - custom_mean_iou: 0.8224
# Epoch 41: val_custom_mean_iou did not improve from 0.80989
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2692 - custom_mean_iou: 0.8224 - val_loss: 0.2923 - val_custom_mean_iou: 0.8020 - lr: 1.0000e-04
# Epoch 42/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2555 - custom_mean_iou: 0.8455
# Epoch 42: val_custom_mean_iou improved from 0.80989 to 0.81326, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 4s 54ms/step - loss: 0.2555 - custom_mean_iou: 0.8455 - val_loss: 0.2764 - val_custom_mean_iou: 0.8133 - lr: 1.0000e-04
# Epoch 43/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2246 - custom_mean_iou: 0.8521
# Epoch 43: val_custom_mean_iou did not improve from 0.81326
# 69/69 [==============================] - 3s 43ms/step - loss: 0.2246 - custom_mean_iou: 0.8521 - val_loss: 0.2989 - val_custom_mean_iou: 0.8027 - lr: 1.0000e-04
# Epoch 44/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2454 - custom_mean_iou: 0.8422
# Epoch 44: val_custom_mean_iou did not improve from 0.81326
# 69/69 [==============================] - 3s 46ms/step - loss: 0.2430 - custom_mean_iou: 0.8442 - val_loss: 0.2912 - val_custom_mean_iou: 0.7991 - lr: 1.0000e-04
# Epoch 45/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2374 - custom_mean_iou: 0.8577
# Epoch 45: val_custom_mean_iou improved from 0.81326 to 0.81976, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 50ms/step - loss: 0.2374 - custom_mean_iou: 0.8577 - val_loss: 0.2999 - val_custom_mean_iou: 0.8198 - lr: 1.0000e-04
# Epoch 46/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2432 - custom_mean_iou: 0.8574
# Epoch 46: val_custom_mean_iou did not improve from 0.81976
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2430 - custom_mean_iou: 0.8576 - val_loss: 0.2814 - val_custom_mean_iou: 0.8166 - lr: 1.0000e-04
# Epoch 47/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2157 - custom_mean_iou: 0.8545
# Epoch 47: val_custom_mean_iou did not improve from 0.81976
# 69/69 [==============================] - 3s 44ms/step - loss: 0.2157 - custom_mean_iou: 0.8545 - val_loss: 0.2820 - val_custom_mean_iou: 0.8015 - lr: 1.0000e-04
# Epoch 48/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2274 - custom_mean_iou: 0.8524
# Epoch 48: val_custom_mean_iou did not improve from 0.81976
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2274 - custom_mean_iou: 0.8524 - val_loss: 0.3013 - val_custom_mean_iou: 0.8014 - lr: 1.0000e-04
# Epoch 49/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2408 - custom_mean_iou: 0.8643
# Epoch 49: val_custom_mean_iou did not improve from 0.81976
# 69/69 [==============================] - 3s 44ms/step - loss: 0.2408 - custom_mean_iou: 0.8643 - val_loss: 0.2802 - val_custom_mean_iou: 0.8031 - lr: 1.0000e-04
# Epoch 50/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2203 - custom_mean_iou: 0.8504
# Epoch 50: val_custom_mean_iou did not improve from 0.81976
# 69/69 [==============================] - 3s 44ms/step - loss: 0.2231 - custom_mean_iou: 0.8518 - val_loss: 0.2730 - val_custom_mean_iou: 0.8126 - lr: 1.0000e-04
# Epoch 51/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2413 - custom_mean_iou: 0.8485
# Epoch 51: val_custom_mean_iou improved from 0.81976 to 0.83741, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 50ms/step - loss: 0.2414 - custom_mean_iou: 0.8491 - val_loss: 0.2570 - val_custom_mean_iou: 0.8374 - lr: 1.0000e-04
# Epoch 52/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2195 - custom_mean_iou: 0.8525
# Epoch 52: val_custom_mean_iou did not improve from 0.83741
# 69/69 [==============================] - 3s 44ms/step - loss: 0.2202 - custom_mean_iou: 0.8524 - val_loss: 0.2693 - val_custom_mean_iou: 0.8135 - lr: 1.0000e-04
# Epoch 53/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2386 - custom_mean_iou: 0.8541
# Epoch 53: val_custom_mean_iou did not improve from 0.83741
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2386 - custom_mean_iou: 0.8541 - val_loss: 0.2626 - val_custom_mean_iou: 0.8318 - lr: 1.0000e-04
# Epoch 54/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2342 - custom_mean_iou: 0.8521
# Epoch 54: val_custom_mean_iou did not improve from 0.83741
# 69/69 [==============================] - 3s 44ms/step - loss: 0.2336 - custom_mean_iou: 0.8527 - val_loss: 0.2795 - val_custom_mean_iou: 0.8105 - lr: 1.0000e-04
# Epoch 55/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2389 - custom_mean_iou: 0.8515
# Epoch 55: val_custom_mean_iou did not improve from 0.83741
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2389 - custom_mean_iou: 0.8515 - val_loss: 0.2577 - val_custom_mean_iou: 0.8211 - lr: 1.0000e-04
# Epoch 56/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2214 - custom_mean_iou: 0.8548
# Epoch 56: val_custom_mean_iou did not improve from 0.83741
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2214 - custom_mean_iou: 0.8548 - val_loss: 0.2718 - val_custom_mean_iou: 0.8333 - lr: 1.0000e-04
# Epoch 57/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2337 - custom_mean_iou: 0.8592
# Epoch 57: val_custom_mean_iou improved from 0.83741 to 0.84183, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_1DCNN-Light-Wonosobo_mIoU.h5
# 69/69 [==============================] - 3s 51ms/step - loss: 0.2314 - custom_mean_iou: 0.8610 - val_loss: 0.2540 - val_custom_mean_iou: 0.8418 - lr: 1.0000e-04
# Epoch 58/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1853 - custom_mean_iou: 0.8710
# Epoch 58: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1836 - custom_mean_iou: 0.8720 - val_loss: 0.2520 - val_custom_mean_iou: 0.8342 - lr: 1.0000e-04
# Epoch 59/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2330 - custom_mean_iou: 0.8398
# Epoch 59: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2330 - custom_mean_iou: 0.8398 - val_loss: 0.2775 - val_custom_mean_iou: 0.8213 - lr: 1.0000e-04
# Epoch 60/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2037 - custom_mean_iou: 0.8643
# Epoch 60: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2037 - custom_mean_iou: 0.8643 - val_loss: 0.2608 - val_custom_mean_iou: 0.8243 - lr: 1.0000e-04
# Epoch 61/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1783 - custom_mean_iou: 0.8722
# Epoch 61: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1786 - custom_mean_iou: 0.8709 - val_loss: 0.2577 - val_custom_mean_iou: 0.8190 - lr: 1.0000e-04
# Epoch 62/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1899 - custom_mean_iou: 0.8759
# Epoch 62: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1899 - custom_mean_iou: 0.8759 - val_loss: 0.2697 - val_custom_mean_iou: 0.8322 - lr: 1.0000e-04
# Epoch 63/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2010 - custom_mean_iou: 0.8573
# Epoch 63: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2010 - custom_mean_iou: 0.8573 - val_loss: 0.2618 - val_custom_mean_iou: 0.8339 - lr: 1.0000e-05
# Epoch 64/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1852 - custom_mean_iou: 0.8657
# Epoch 64: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1852 - custom_mean_iou: 0.8657 - val_loss: 0.2583 - val_custom_mean_iou: 0.8278 - lr: 1.0000e-05
# Epoch 65/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1777 - custom_mean_iou: 0.8887
# Epoch 65: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1818 - custom_mean_iou: 0.8876 - val_loss: 0.2610 - val_custom_mean_iou: 0.8320 - lr: 1.0000e-05
# Epoch 66/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2023 - custom_mean_iou: 0.8540
# Epoch 66: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2022 - custom_mean_iou: 0.8552 - val_loss: 0.2580 - val_custom_mean_iou: 0.8320 - lr: 1.0000e-05
# Epoch 67/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2110 - custom_mean_iou: 0.8591
# Epoch 67: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.2110 - custom_mean_iou: 0.8591 - val_loss: 0.2567 - val_custom_mean_iou: 0.8254 - lr: 1.0000e-05
# Epoch 68/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1940 - custom_mean_iou: 0.8723
# Epoch 68: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1918 - custom_mean_iou: 0.8740 - val_loss: 0.2549 - val_custom_mean_iou: 0.8227 - lr: 1.0000e-05
# Epoch 69/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1785 - custom_mean_iou: 0.8837
# Epoch 69: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1785 - custom_mean_iou: 0.8837 - val_loss: 0.2519 - val_custom_mean_iou: 0.8280 - lr: 1.0000e-05
# Epoch 70/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1930 - custom_mean_iou: 0.8628
# Epoch 70: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1930 - custom_mean_iou: 0.8628 - val_loss: 0.2542 - val_custom_mean_iou: 0.8254 - lr: 1.0000e-05
# Epoch 71/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1650 - custom_mean_iou: 0.8936
# Epoch 71: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1652 - custom_mean_iou: 0.8936 - val_loss: 0.2550 - val_custom_mean_iou: 0.8285 - lr: 1.0000e-05
# Epoch 72/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1715 - custom_mean_iou: 0.8772
# Epoch 72: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1702 - custom_mean_iou: 0.8771 - val_loss: 0.2541 - val_custom_mean_iou: 0.8285 - lr: 1.0000e-05
# Epoch 73/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1877 - custom_mean_iou: 0.8795
# Epoch 73: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1877 - custom_mean_iou: 0.8795 - val_loss: 0.2550 - val_custom_mean_iou: 0.8254 - lr: 1.0000e-05
# Epoch 74/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1996 - custom_mean_iou: 0.8710
# Epoch 74: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1996 - custom_mean_iou: 0.8710 - val_loss: 0.2582 - val_custom_mean_iou: 0.8251 - lr: 1.0000e-05
# Epoch 75/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1941 - custom_mean_iou: 0.8694
# Epoch 75: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1930 - custom_mean_iou: 0.8689 - val_loss: 0.2599 - val_custom_mean_iou: 0.8251 - lr: 1.0000e-05
# Epoch 76/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1818 - custom_mean_iou: 0.8691
# Epoch 76: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1818 - custom_mean_iou: 0.8691 - val_loss: 0.2518 - val_custom_mean_iou: 0.8226 - lr: 1.0000e-05
# Epoch 77/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1907 - custom_mean_iou: 0.8605
# Epoch 77: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1907 - custom_mean_iou: 0.8605 - val_loss: 0.2521 - val_custom_mean_iou: 0.8195 - lr: 1.0000e-05
# Epoch 78/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1633 - custom_mean_iou: 0.8947
# Epoch 78: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1657 - custom_mean_iou: 0.8926 - val_loss: 0.2535 - val_custom_mean_iou: 0.8227 - lr: 1.0000e-05
# Epoch 79/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1869 - custom_mean_iou: 0.8832
# Epoch 79: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1846 - custom_mean_iou: 0.8840 - val_loss: 0.2540 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# Epoch 80/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1762 - custom_mean_iou: 0.8854
# Epoch 80: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1762 - custom_mean_iou: 0.8854 - val_loss: 0.2532 - val_custom_mean_iou: 0.8227 - lr: 1.0000e-05
# Epoch 81/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1862 - custom_mean_iou: 0.8864
# Epoch 81: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1854 - custom_mean_iou: 0.8859 - val_loss: 0.2522 - val_custom_mean_iou: 0.8206 - lr: 1.0000e-05
# Epoch 82/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1738 - custom_mean_iou: 0.8774
# Epoch 82: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1734 - custom_mean_iou: 0.8769 - val_loss: 0.2549 - val_custom_mean_iou: 0.8223 - lr: 1.0000e-05
# Epoch 83/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1827 - custom_mean_iou: 0.8852
# Epoch 83: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1827 - custom_mean_iou: 0.8852 - val_loss: 0.2552 - val_custom_mean_iou: 0.8166 - lr: 1.0000e-05
# Epoch 84/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2097 - custom_mean_iou: 0.8734
# Epoch 84: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.2097 - custom_mean_iou: 0.8734 - val_loss: 0.2580 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-05
# Epoch 85/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1828 - custom_mean_iou: 0.8774
# Epoch 85: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1828 - custom_mean_iou: 0.8774 - val_loss: 0.2604 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-05
# Epoch 86/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1854 - custom_mean_iou: 0.8749
# Epoch 86: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 49ms/step - loss: 0.1843 - custom_mean_iou: 0.8765 - val_loss: 0.2560 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-05
# Epoch 87/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1986 - custom_mean_iou: 0.8736
# Epoch 87: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 49ms/step - loss: 0.1986 - custom_mean_iou: 0.8736 - val_loss: 0.2574 - val_custom_mean_iou: 0.8241 - lr: 1.0000e-05
# Epoch 88/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1900 - custom_mean_iou: 0.8788
# Epoch 88: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1883 - custom_mean_iou: 0.8794 - val_loss: 0.2533 - val_custom_mean_iou: 0.8241 - lr: 1.0000e-05
# Epoch 89/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1744 - custom_mean_iou: 0.8987
# Epoch 89: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1736 - custom_mean_iou: 0.8986 - val_loss: 0.2555 - val_custom_mean_iou: 0.8249 - lr: 1.0000e-05
# Epoch 90/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1947 - custom_mean_iou: 0.8688
# Epoch 90: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1963 - custom_mean_iou: 0.8668 - val_loss: 0.2539 - val_custom_mean_iou: 0.8249 - lr: 1.0000e-05
# Epoch 91/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1852 - custom_mean_iou: 0.8833
# Epoch 91: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1862 - custom_mean_iou: 0.8798 - val_loss: 0.2574 - val_custom_mean_iou: 0.8270 - lr: 1.0000e-05
# Epoch 92/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1928 - custom_mean_iou: 0.8779
# Epoch 92: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 48ms/step - loss: 0.1928 - custom_mean_iou: 0.8779 - val_loss: 0.2569 - val_custom_mean_iou: 0.8223 - lr: 1.0000e-05
# Epoch 93/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1615 - custom_mean_iou: 0.8940
# Epoch 93: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1615 - custom_mean_iou: 0.8940 - val_loss: 0.2539 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 94/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1840 - custom_mean_iou: 0.8793
# Epoch 94: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1840 - custom_mean_iou: 0.8793 - val_loss: 0.2531 - val_custom_mean_iou: 0.8240 - lr: 1.0000e-05
# Epoch 95/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2066 - custom_mean_iou: 0.8620
# Epoch 95: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 47ms/step - loss: 0.2066 - custom_mean_iou: 0.8620 - val_loss: 0.2561 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 96/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1699 - custom_mean_iou: 0.8859
# Epoch 96: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1699 - custom_mean_iou: 0.8859 - val_loss: 0.2532 - val_custom_mean_iou: 0.8292 - lr: 1.0000e-05
# Epoch 97/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1618 - custom_mean_iou: 0.8882
# Epoch 97: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1638 - custom_mean_iou: 0.8855 - val_loss: 0.2506 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 98/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1779 - custom_mean_iou: 0.8754
# Epoch 98: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1779 - custom_mean_iou: 0.8754 - val_loss: 0.2513 - val_custom_mean_iou: 0.8333 - lr: 1.0000e-05
# Epoch 99/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1930 - custom_mean_iou: 0.8760
# Epoch 99: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1936 - custom_mean_iou: 0.8746 - val_loss: 0.2522 - val_custom_mean_iou: 0.8269 - lr: 1.0000e-05
# Epoch 100/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1784 - custom_mean_iou: 0.8753
# Epoch 100: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1784 - custom_mean_iou: 0.8753 - val_loss: 0.2561 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 101/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1824 - custom_mean_iou: 0.8927
# Epoch 101: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1806 - custom_mean_iou: 0.8942 - val_loss: 0.2534 - val_custom_mean_iou: 0.8221 - lr: 1.0000e-05
# Epoch 102/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1892 - custom_mean_iou: 0.8731
# Epoch 102: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1892 - custom_mean_iou: 0.8731 - val_loss: 0.2543 - val_custom_mean_iou: 0.8221 - lr: 1.0000e-05
# Epoch 103/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1617 - custom_mean_iou: 0.8963
# Epoch 103: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1641 - custom_mean_iou: 0.8955 - val_loss: 0.2543 - val_custom_mean_iou: 0.8221 - lr: 1.0000e-05
# Epoch 104/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1947 - custom_mean_iou: 0.8757
# Epoch 104: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1947 - custom_mean_iou: 0.8757 - val_loss: 0.2500 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 105/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1794 - custom_mean_iou: 0.8919
# Epoch 105: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1787 - custom_mean_iou: 0.8919 - val_loss: 0.2493 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 106/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1724 - custom_mean_iou: 0.8855
# Epoch 106: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1724 - custom_mean_iou: 0.8855 - val_loss: 0.2496 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 107/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1728 - custom_mean_iou: 0.8806
# Epoch 107: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1733 - custom_mean_iou: 0.8792 - val_loss: 0.2489 - val_custom_mean_iou: 0.8304 - lr: 1.0000e-05
# Epoch 108/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1911 - custom_mean_iou: 0.8614
# Epoch 108: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1893 - custom_mean_iou: 0.8626 - val_loss: 0.2532 - val_custom_mean_iou: 0.8314 - lr: 1.0000e-05
# Epoch 109/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1760 - custom_mean_iou: 0.8940
# Epoch 109: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1760 - custom_mean_iou: 0.8940 - val_loss: 0.2499 - val_custom_mean_iou: 0.8259 - lr: 1.0000e-05
# Epoch 110/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1747 - custom_mean_iou: 0.8788
# Epoch 110: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1747 - custom_mean_iou: 0.8788 - val_loss: 0.2453 - val_custom_mean_iou: 0.8387 - lr: 1.0000e-05
# Epoch 111/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1763 - custom_mean_iou: 0.8679
# Epoch 111: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1763 - custom_mean_iou: 0.8679 - val_loss: 0.2432 - val_custom_mean_iou: 0.8418 - lr: 1.0000e-05
# Epoch 112/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1853 - custom_mean_iou: 0.8668
# Epoch 112: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 4s 57ms/step - loss: 0.1853 - custom_mean_iou: 0.8668 - val_loss: 0.2417 - val_custom_mean_iou: 0.8398 - lr: 1.0000e-05
# Epoch 113/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1933 - custom_mean_iou: 0.8876
# Epoch 113: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 4s 65ms/step - loss: 0.1933 - custom_mean_iou: 0.8876 - val_loss: 0.2434 - val_custom_mean_iou: 0.8356 - lr: 1.0000e-05
# Epoch 114/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1690 - custom_mean_iou: 0.8861
# Epoch 114: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 48ms/step - loss: 0.1690 - custom_mean_iou: 0.8861 - val_loss: 0.2429 - val_custom_mean_iou: 0.8330 - lr: 1.0000e-05
# Epoch 115/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1682 - custom_mean_iou: 0.8779
# Epoch 115: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1682 - custom_mean_iou: 0.8779 - val_loss: 0.2415 - val_custom_mean_iou: 0.8376 - lr: 1.0000e-05
# Epoch 116/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1593 - custom_mean_iou: 0.8928
# Epoch 116: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 47ms/step - loss: 0.1593 - custom_mean_iou: 0.8928 - val_loss: 0.2464 - val_custom_mean_iou: 0.8309 - lr: 1.0000e-05
# Epoch 117/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1773 - custom_mean_iou: 0.8675
# Epoch 117: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1755 - custom_mean_iou: 0.8677 - val_loss: 0.2456 - val_custom_mean_iou: 0.8299 - lr: 1.0000e-05
# Epoch 118/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1652 - custom_mean_iou: 0.8957
# Epoch 118: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1652 - custom_mean_iou: 0.8957 - val_loss: 0.2477 - val_custom_mean_iou: 0.8304 - lr: 1.0000e-05
# Epoch 119/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1838 - custom_mean_iou: 0.8744
# Epoch 119: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1838 - custom_mean_iou: 0.8744 - val_loss: 0.2520 - val_custom_mean_iou: 0.8277 - lr: 1.0000e-05
# Epoch 120/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1731 - custom_mean_iou: 0.8758
# Epoch 120: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1731 - custom_mean_iou: 0.8758 - val_loss: 0.2488 - val_custom_mean_iou: 0.8296 - lr: 1.0000e-05
# Epoch 121/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1644 - custom_mean_iou: 0.8902
# Epoch 121: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1644 - custom_mean_iou: 0.8902 - val_loss: 0.2484 - val_custom_mean_iou: 0.8277 - lr: 1.0000e-05
# Epoch 122/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1730 - custom_mean_iou: 0.8859
# Epoch 122: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1730 - custom_mean_iou: 0.8859 - val_loss: 0.2526 - val_custom_mean_iou: 0.8304 - lr: 1.0000e-05
# Epoch 123/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1884 - custom_mean_iou: 0.8726
# Epoch 123: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1884 - custom_mean_iou: 0.8726 - val_loss: 0.2543 - val_custom_mean_iou: 0.8321 - lr: 1.0000e-05
# Epoch 124/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1841 - custom_mean_iou: 0.8787
# Epoch 124: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1841 - custom_mean_iou: 0.8787 - val_loss: 0.2504 - val_custom_mean_iou: 0.8271 - lr: 1.0000e-05
# Epoch 125/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1760 - custom_mean_iou: 0.8812
# Epoch 125: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1745 - custom_mean_iou: 0.8832 - val_loss: 0.2504 - val_custom_mean_iou: 0.8301 - lr: 1.0000e-05
# Epoch 126/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1919 - custom_mean_iou: 0.8838
# Epoch 126: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1919 - custom_mean_iou: 0.8838 - val_loss: 0.2465 - val_custom_mean_iou: 0.8296 - lr: 1.0000e-05
# Epoch 127/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1630 - custom_mean_iou: 0.8841
# Epoch 127: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1630 - custom_mean_iou: 0.8841 - val_loss: 0.2464 - val_custom_mean_iou: 0.8296 - lr: 1.0000e-05
# Epoch 128/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1663 - custom_mean_iou: 0.8920
# Epoch 128: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1663 - custom_mean_iou: 0.8920 - val_loss: 0.2451 - val_custom_mean_iou: 0.8349 - lr: 1.0000e-05
# Epoch 129/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2043 - custom_mean_iou: 0.8906
# Epoch 129: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.2043 - custom_mean_iou: 0.8906 - val_loss: 0.2468 - val_custom_mean_iou: 0.8272 - lr: 1.0000e-05
# Epoch 130/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1890 - custom_mean_iou: 0.8766
# Epoch 130: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1876 - custom_mean_iou: 0.8784 - val_loss: 0.2474 - val_custom_mean_iou: 0.8335 - lr: 1.0000e-05
# Epoch 131/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1672 - custom_mean_iou: 0.8896
# Epoch 131: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 48ms/step - loss: 0.1672 - custom_mean_iou: 0.8896 - val_loss: 0.2469 - val_custom_mean_iou: 0.8335 - lr: 1.0000e-05
# Epoch 132/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1964 - custom_mean_iou: 0.8711
# Epoch 132: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1964 - custom_mean_iou: 0.8711 - val_loss: 0.2478 - val_custom_mean_iou: 0.8335 - lr: 1.0000e-05
# Epoch 133/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1762 - custom_mean_iou: 0.8726
# Epoch 133: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1757 - custom_mean_iou: 0.8722 - val_loss: 0.2508 - val_custom_mean_iou: 0.8309 - lr: 1.0000e-05
# Epoch 134/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1919 - custom_mean_iou: 0.8715
# Epoch 134: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1931 - custom_mean_iou: 0.8717 - val_loss: 0.2484 - val_custom_mean_iou: 0.8303 - lr: 1.0000e-05
# Epoch 135/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1771 - custom_mean_iou: 0.8764
# Epoch 135: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1791 - custom_mean_iou: 0.8743 - val_loss: 0.2482 - val_custom_mean_iou: 0.8303 - lr: 1.0000e-05
# Epoch 136/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1852 - custom_mean_iou: 0.8720
# Epoch 136: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1830 - custom_mean_iou: 0.8732 - val_loss: 0.2438 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# Epoch 137/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1720 - custom_mean_iou: 0.8829
# Epoch 137: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1720 - custom_mean_iou: 0.8829 - val_loss: 0.2414 - val_custom_mean_iou: 0.8329 - lr: 1.0000e-05
# Epoch 138/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1730 - custom_mean_iou: 0.8929
# Epoch 138: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1730 - custom_mean_iou: 0.8929 - val_loss: 0.2434 - val_custom_mean_iou: 0.8329 - lr: 1.0000e-05
# Epoch 139/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1764 - custom_mean_iou: 0.8894
# Epoch 139: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1745 - custom_mean_iou: 0.8908 - val_loss: 0.2420 - val_custom_mean_iou: 0.8335 - lr: 1.0000e-05
# Epoch 140/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1745 - custom_mean_iou: 0.8901
# Epoch 140: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1745 - custom_mean_iou: 0.8901 - val_loss: 0.2503 - val_custom_mean_iou: 0.8335 - lr: 1.0000e-05
# Epoch 141/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1499 - custom_mean_iou: 0.8912
# Epoch 141: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1499 - custom_mean_iou: 0.8912 - val_loss: 0.2470 - val_custom_mean_iou: 0.8309 - lr: 1.0000e-05
# Epoch 142/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1492 - custom_mean_iou: 0.8897
# Epoch 142: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1492 - custom_mean_iou: 0.8897 - val_loss: 0.2472 - val_custom_mean_iou: 0.8256 - lr: 1.0000e-05
# Epoch 143/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1768 - custom_mean_iou: 0.8885
# Epoch 143: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1768 - custom_mean_iou: 0.8885 - val_loss: 0.2467 - val_custom_mean_iou: 0.8342 - lr: 1.0000e-05
# Epoch 144/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1790 - custom_mean_iou: 0.8799
# Epoch 144: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1790 - custom_mean_iou: 0.8799 - val_loss: 0.2532 - val_custom_mean_iou: 0.8309 - lr: 1.0000e-05
# Epoch 145/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1620 - custom_mean_iou: 0.8876
# Epoch 145: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1620 - custom_mean_iou: 0.8876 - val_loss: 0.2527 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# Epoch 146/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1597 - custom_mean_iou: 0.8835
# Epoch 146: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 46ms/step - loss: 0.1582 - custom_mean_iou: 0.8852 - val_loss: 0.2496 - val_custom_mean_iou: 0.8277 - lr: 1.0000e-05
# Epoch 147/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1617 - custom_mean_iou: 0.9103
# Epoch 147: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1617 - custom_mean_iou: 0.9103 - val_loss: 0.2508 - val_custom_mean_iou: 0.8253 - lr: 1.0000e-05
# Epoch 148/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1566 - custom_mean_iou: 0.8962
# Epoch 148: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1566 - custom_mean_iou: 0.8962 - val_loss: 0.2491 - val_custom_mean_iou: 0.8303 - lr: 1.0000e-05
# Epoch 149/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1544 - custom_mean_iou: 0.8982
# Epoch 149: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1544 - custom_mean_iou: 0.8982 - val_loss: 0.2510 - val_custom_mean_iou: 0.8256 - lr: 1.0000e-05
# Epoch 150/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1740 - custom_mean_iou: 0.8965
# Epoch 150: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1768 - custom_mean_iou: 0.8935 - val_loss: 0.2509 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# Epoch 151/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1805 - custom_mean_iou: 0.8795
# Epoch 151: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1799 - custom_mean_iou: 0.8798 - val_loss: 0.2533 - val_custom_mean_iou: 0.8256 - lr: 1.0000e-05
# Epoch 152/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1659 - custom_mean_iou: 0.8872
# Epoch 152: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1659 - custom_mean_iou: 0.8872 - val_loss: 0.2562 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# Epoch 153/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1635 - custom_mean_iou: 0.8979
# Epoch 153: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1621 - custom_mean_iou: 0.8995 - val_loss: 0.2569 - val_custom_mean_iou: 0.8256 - lr: 1.0000e-05
# Epoch 154/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1725 - custom_mean_iou: 0.8827
# Epoch 154: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1738 - custom_mean_iou: 0.8828 - val_loss: 0.2562 - val_custom_mean_iou: 0.8256 - lr: 1.0000e-05
# Epoch 155/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1784 - custom_mean_iou: 0.8815
# Epoch 155: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 44ms/step - loss: 0.1780 - custom_mean_iou: 0.8815 - val_loss: 0.2556 - val_custom_mean_iou: 0.8221 - lr: 1.0000e-05
# Epoch 156/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1667 - custom_mean_iou: 0.8834
# Epoch 156: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 3s 45ms/step - loss: 0.1653 - custom_mean_iou: 0.8833 - val_loss: 0.2560 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# Epoch 157/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1645 - custom_mean_iou: 0.8849
# Epoch 157: val_custom_mean_iou did not improve from 0.84183
# 69/69 [==============================] - 4s 59ms/step - loss: 0.1645 - custom_mean_iou: 0.8849 - val_loss: 0.2545 - val_custom_mean_iou: 0.8282 - lr: 1.0000e-05
# CPU times: total: 23min 27s
# Wall time: 8min 30s

# %%
n_epochs = len(history.history['loss'])

acc = history.history['custom_mean_iou']
val_acc = history.history['val_custom_mean_iou']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(n_epochs) #change it based on epoch needed to finish building the model

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

labels, counts = np.unique(y, return_counts=True)
labels = labels -1
classes = ['Forest','Plantation','Agriculture', 'Shrubland', 'Bareland', 'Urban', 'Waterbody']

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)
score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred, labels=labels)

# plot the confusion matrix of LGB
dl_cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(dl_cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)


# Show all labels
ax.set(xticks=np.arange(dl_cm.shape[1]),
        yticks=np.arange(dl_cm.shape[0]),
        # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,
        title='Normalized Confusion Matrix',
        ylabel='True label',
        xlabel='Predicted label')

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
          rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
fmt = '.2f'
thresh = dl_cm.max() / 2.
for i in range(dl_cm.shape[0]):
    for j in range(dl_cm.shape[1]):
        ax.text(j, i, format(dl_cm[i, j], fmt),
                ha="center", va="center",
                color="white" if dl_cm[i, j] > thresh else "black")
fig.tight_layout()
# Out:
# 19/19 [==============================] - 2s 22ms/step

# %%
# Calculate per-class IoU and mean IoU from raw confusion matrix
def calculate_iou_from_cm(cm):
    n_classes = cm.shape[0]
    class_iou = np.zeros(n_classes)
    
    for i in range(n_classes):
        # True positives: diagonal elements
        tp = cm[i, i]
        
        # False positives: sum of column i minus diagonal element
        fp = np.sum(cm[:, i]) - tp
        
        # False negatives: sum of row i minus diagonal element
        fn = np.sum(cm[i, :]) - tp
        
        # IoU calculation
        if tp + fp + fn == 0:
            class_iou[i] = 0
        else:
            class_iou[i] = tp / (tp + fp + fn)
    
    # Calculate mean IoU
    mean_iou = np.mean(class_iou)
    
    return class_iou, mean_iou

# Use your raw confusion matrix (before normalization)
class_iou, mean_iou = calculate_iou_from_cm(cm)  # 'cm' is your raw confusion matrix

print("Class IoU values:")
for i, class_name in enumerate(classes):
    print(f"{class_name}: {class_iou[i]:.4f}")
print(f"Mean IoU: {mean_iou:.4f}")

# %%
#Metric Precision, Recall, F-score support
from sklearn.metrics import precision_recall_fscore_support

y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)

macro_01 = precision_recall_fscore_support(y_test, y_pred, average='macro')
weighted_01 = precision_recall_fscore_support(y_test, y_pred, average='weighted')

print(macro_01)
print(weighted_01)
# Out:
# 19/19 [==============================] - 0s 21ms/step
# (0.8994681677425538, 0.9314936114813754, 0.9108087619756697, None)
# (0.9374366184444878, 0.9307432432432432, 0.9320861517316837, None)

# %%
#Metric F1-score
from sklearn.metrics import f1_score

macro_02 = f1_score(y_test, y_pred, average='macro')
weighted_02 = f1_score(y_test, y_pred, average='weighted')

print(macro_02)
print(weighted_02)
# Out:
# 0.9108087619756697
# 0.9320861517316837

# %%
# Print the precision and recall, among other metrics
from sklearn import metrics
from tensorflow.compat.v1.keras.models import load_model

# model = load_model('D:/Wiltang_2022/Paper_Data_Codes/Saved_Model/LC_Multivariate_Wonosobo_BiGRU_exp_ver01_metricmeasurement.h5')
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# y_test = y_test.argmax(axis=1)

print(metrics.classification_report(y_test, y_pred, digits=4))
# Out:
# 19/19 [==============================] - 0s 19ms/step
#               precision    recall  f1-score   support
#
#            0     0.8636    0.9661    0.9120        59
#            1     0.9271    0.9271    0.9271        96
#            2     0.9728    0.8994    0.9346       159
#            3     0.6667    0.9600    0.7869        25
#            4     0.9000    0.8333    0.8654        54
#            5     0.9661    0.9828    0.9744       116
#            6     1.0000    0.9518    0.9753        83
#
#     accuracy                         0.9307       592
#    macro avg     0.8995    0.9315    0.9108       592
# weighted avg     0.9374    0.9307    0.9321       592

# %%
import numpy as np
from sklearn.metrics import jaccard_score

y_pred_train = model.predict(X_train)
y_pred_train = y_pred_train.argmax(axis=1)
y_train = y_train.argmax(axis=1)

JS_test = jaccard_score(y_test, y_pred, average='macro')
JS_train = jaccard_score(y_train, y_pred_train, average='macro')
print(JS_test)
print(JS_train)
# Out:
# 44/44 [==============================] - 1s 20ms/step
# 0.8418259027840833
# 0.9183818562680875

# %%
import numpy as np
from sklearn.metrics import jaccard_score

y_pred_train = model.predict(X_train)
y_pred_train = y_pred_train.argmax(axis=1)
# y_train = y_train.argmax(axis=1)

JS_test = jaccard_score(y_test, y_pred, average=None)
JS_train = jaccard_score(y_train, y_pred_train, average=None)
print(JS_test)
print(JS_train)
# Out:
# 44/44 [==============================] - 1s 17ms/step
# [0.83823529 0.86407767 0.87730061 0.64864865 0.76271186 0.95
#  0.95180723]
# [0.91208791 0.93782383 0.93643032 0.78409091 0.87969925 0.97854077
#  1.        ]

# %%
from sklearn.metrics import cohen_kappa_score

model_kappa = cohen_kappa_score(y_pred, y_test)
print(model_kappa)
# Out:
# 0.9163426806738909

# %%
# data_test = {'ytest': y_test,
#         'ytest_pred': y_pred}

# data_train = {'ytest': y_train,
#         'ytest_pred': y_pred_train}

# df_test = pd.DataFrame(data_test)
# df_train = pd.DataFrame(data_train)

# df_test.to_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/df_test.csv')
# df_train.to_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/df_train.csv')

# %%
# from tensorflow.keras.utils import plot_model
# import pydot
# import pydotplus
# from pydotplus import graphviz

# plot_model(model, to_file='D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model/model3_plot.png', 
#            show_shapes=True, show_layer_names=True)
