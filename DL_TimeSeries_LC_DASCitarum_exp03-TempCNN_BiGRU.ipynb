# %%
# import tensorflow as tf
# tf.test.is_built_with_cuda()
# tf.config.list_physical_devices('GPU')

# %%
# import tensorflow as tf
# tf.__version__

# %%
import tensorflow as tf
tf.__version__
tf.keras.backend.clear_session()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
# import keras.backend as K
# from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.backend import sigmoid
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l1,l2, l1_l2
# from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Layer, Permute, multiply
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Conv1D, Dropout, Dense, BatchNormalization, AveragePooling1D, ReLU, LayerNormalization
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Lambda, Reshape, Flatten, SeparableConv1D, Activation, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Add, MaxPooling1D, MultiHeadAttention, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.compat.v1.keras.models import load_model
# from tensorflow.compat.v1.keras.layers import CuDNNGRU
import sklearn
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight

# %%
# data_b2= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B2_final.csv')
# data_b3= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B3_final.csv')
# data_b4= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B4_final.csv')
# data_b5= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B5_final.csv')
# data_b6= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B6_final.csv')
# data_b7= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B7_final.csv')
# data_b8= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B8_final.csv')
# data_b8A= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B8A_final.csv')
# data_b11= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B11_final.csv')
# data_b12= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Sentinel/Refined_Data/B12_final.csv')

data_cbi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/CBI_final.csv')
data_bsi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/BSI_final.csv')
data_evi2= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/EVI2_final.csv')
data_mndwi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/MNDWI_final.csv')
data_msavi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/MSAVI_final.csv')
data_nbr= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/NBR_final.csv')
data_ndvi= pd.read_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Refined_Data/NDVI_final.csv')

# %%
# print(data_cbi.columns)

# %%
# print(data_cbi.Class)

# %%
#interpolate NaN for each row
# data_b2 = data_b2.apply(pd.to_numeric, errors='coerce')
# data_b3 = data_b3.apply(pd.to_numeric, errors='coerce')
# data_b4 = data_b4.apply(pd.to_numeric, errors='coerce')
# data_b5 = data_b5.apply(pd.to_numeric, errors='coerce')
# data_b6 = data_b6.apply(pd.to_numeric, errors='coerce')
# data_b7 = data_b7.apply(pd.to_numeric, errors='coerce')
# data_b8 = data_b8.apply(pd.to_numeric, errors='coerce')
# data_b8A = data_b8A.apply(pd.to_numeric, errors='coerce')
# data_b11 = data_b11.apply(pd.to_numeric, errors='coerce')
# data_b12 = data_b12.apply(pd.to_numeric, errors='coerce')

data_cbi_ = data_cbi.values
data_bsi_ = data_bsi.values
data_evi2_ = data_evi2.values
data_mndwi_ = data_mndwi.values
data_msavi_ = data_msavi.values
data_nbr_ = data_nbr.values
data_ndvi_ = data_ndvi.values

cbi_pd = pd.DataFrame(data_cbi_)
bsi_pd = pd.DataFrame(data_bsi_)
evi2_pd = pd.DataFrame(data_evi2_)
mndwi_pd = pd.DataFrame(data_mndwi_)
msavi_pd = pd.DataFrame(data_msavi_)
nbr_pd = pd.DataFrame(data_nbr_)
ndvi_pd = pd.DataFrame(data_ndvi_)

cbi_pd = cbi_pd.iloc[:,3:42].astype(float)
bsi_pd = bsi_pd.iloc[:,3:42].astype(float)
evi2_pd  = evi2_pd.iloc[:,3:42].astype(float)
mndwi_pd  = mndwi_pd.iloc[:,3:42].astype(float)
msavi_pd = msavi_pd.iloc[:,3:42].astype(float)
nbr_pd  = nbr_pd.iloc[:,3:42].astype(float)
ndvi_pd  = ndvi_pd.iloc[:,3:42].astype(float)

# data_b2_int = data_b2.interpolate(method='linear', limit_direction='both', axis=1)
# data_b3_int = data_b3.interpolate(method='linear', limit_direction='both', axis=1)
# data_b4_int = data_b4.interpolate(method='linear', limit_direction='both', axis=1)
# data_b5_int = data_b5.interpolate(method='linear', limit_direction='both', axis=1)
# data_b6_int = data_b6.interpolate(method='linear', limit_direction='both', axis=1)
# data_b7_int = data_b7.interpolate(method='linear', limit_direction='both', axis=1)
# data_b8_int = data_b8.interpolate(method='linear', limit_direction='both', axis=1)
# data_b8A_int = data_b8A.interpolate(method='linear', limit_direction='both', axis=1)
# data_b11_int = data_b11.interpolate(method='linear', limit_direction='both', axis=1)
# data_b12_int = data_b12.interpolate(method='linear', limit_direction='both', axis=1)

data_cbi_int = cbi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_bsi_int = bsi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_evi2_int = evi2_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_mndwi_int = mndwi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_msavi_int = msavi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_nbr_int = nbr_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)
data_ndvi_int = ndvi_pd.interpolate(method='spline', order=3, limit_direction='both', axis=1)

# print('Number of nan for B2 after:', data_b2_int.isnull().sum().sum())
# print('Number of nan for B3 after:', data_b3_int.isnull().sum().sum())
# print('Number of nan for B4 after:', data_b4_int.isnull().sum().sum())
# print('Number of nan for B5 after:', data_b5_int.isnull().sum().sum())
# print('Number of nan for B6 after:', data_b6_int.isnull().sum().sum())
# print('Number of nan for B7 after:', data_b7_int.isnull().sum().sum())
# print('Number of nan for B8 after:', data_b8_int.isnull().sum().sum())
# print('Number of nan for B8A after:', data_b8A_int.isnull().sum().sum())
# print('Number of nan for B11 after:', data_b11_int.isnull().sum().sum())
# print('Number of nan for B12 after:', data_b12_int.isnull().sum().sum())

print('Number of nan for CBI after:', np.count_nonzero(np.isnan(data_cbi_int)))
print('Number of nan for BSI after:', np.count_nonzero(np.isnan(data_bsi_int)))
print('Number of nan for EVI2 after:', np.count_nonzero(np.isnan(data_evi2_int)))
print('Number of nan for MNDWI after:', data_mndwi_int.isnull().sum().sum())
print('Number of nan for MSAVI after:', data_msavi_int.isnull().sum().sum())
print('Number of nan for NBR after:', data_nbr_int.isnull().sum().sum())
print('Number of nan for NDVI after:', data_ndvi_int.isnull().sum().sum())
# Out:
# Number of nan for CBI after: 0
# Number of nan for BSI after: 0
# Number of nan for EVI2 after: 0
# Number of nan for MNDWI after: 0
# Number of nan for MSAVI after: 0
# Number of nan for NBR after: 0
# Number of nan for NDVI after: 0

# %%
# print(data_cbi_int.max())
# print(data_bsi_int.max())
# print(data_evi2_int.max())
# print(data_mndwi_int.max())
# print(data_msavi_int.max())
# print(data_nbr_int.max())
# print(data_ndvi_int.max())

# %%
comb_all = pd.concat([data_cbi_int, data_bsi_int, data_evi2_int,
                      data_mndwi_int, data_msavi_int, 
                      data_nbr_int, data_ndvi_int], axis =0, ignore_index=True)

# %%
comb_all_lc = pd.concat([data_cbi.iloc[:,0:3], data_bsi.iloc[:,0:3], data_evi2.iloc[:,0:3],
                            data_mndwi.iloc[:,0:3], data_msavi.iloc[:,0:3],
                            data_nbr.iloc[:,0:3], data_ndvi.iloc[:,0:3]], axis =0, ignore_index=True)

# %%
# print(comb_all_lc.Class.value_counts())

# %%
y = data_cbi.iloc[:,2]
y = np.asarray(y).astype(np.float32)
y_cat = to_categorical(y)
y_cat = y_cat[:,1:8] # num_class + 1

# %%
# print(y.shape)

# %%
# print(y_cat)
# print(y_cat.shape)

# %%
# print(np.unique(y))

# %%
class_weights = compute_class_weight(class_weight = "balanced",
                                      classes = np.unique(y), y=y)
class_weights = dict(enumerate(class_weights))
# class_weights = dict(zip(np.unique(train_classes), class_weights))
print(class_weights)
# Out:
# {0: 1.2355889724310778, 1: 0.985014985014985, 2: 0.4977284199899041, 3: 2.9969604863221884, 4: 1.5916061339790153, 5: 0.8072042570609906, 6: 1.0357142857142858}

# %%
# print(comb_all.shape)
# print(comb_all)

# %%
# comb_b2 = comb_all.iloc[0:1939:,3:31]
# comb_b3 = comb_all.iloc[1939:3878:,3:31]
# comb_b4 = comb_all.iloc[3878:5817:,3:31]
# comb_b5 = comb_all.iloc[5817:7756:,3:31]
# comb_b6 = comb_all.iloc[7756:9695:,3:31]
# comb_b7 = comb_all.iloc[9695:11634:,3:31]
# comb_b8 = comb_all.iloc[11634:13573:,3:31]
# comb_b8A = comb_all.iloc[13573:15512:,3:31]
# comb_b11 = comb_all.iloc[15512:17451:,3:31]
# comb_b12 = comb_all.iloc[17451:19390:,3:31]

comb_cbi = comb_all.iloc[0:1972:,:]
comb_bsi = comb_all.iloc[1972:3944:,:]
comb_evi2 = comb_all.iloc[3944:5916:,:]
comb_mndwi = comb_all.iloc[5916:7888:,:]
comb_msavi = comb_all.iloc[7888:9860:,:]
comb_nbr = comb_all.iloc[9860:11832:,:]
comb_ndvi = comb_all.iloc[11832:13804:,:]

# comb_b2= np.asarray(comb_b2).astype(np.float32)
# comb_b3= np.asarray(comb_b3).astype(np.float32)
# comb_b4= np.asarray(comb_b4).astype(np.float32)
# comb_b5= np.asarray(comb_b5).astype(np.float32)
# comb_b6= np.asarray(comb_b6).astype(np.float32)
# comb_b7= np.asarray(comb_b7).astype(np.float32)
# comb_b8= np.asarray(comb_b8).astype(np.float32)
# comb_b8A= np.asarray(comb_b8A).astype(np.float32)
# comb_b11= np.asarray(comb_b11).astype(np.float32)
# comb_b12= np.asarray(comb_b12).astype(np.float32)

comb_cbi= np.asarray(comb_cbi).astype(np.float64)
comb_bsi= np.asarray(comb_bsi).astype(np.float64)
comb_evi2= np.asarray(comb_evi2).astype(np.float64)
comb_mndwi= np.asarray(comb_mndwi).astype(np.float64)
comb_msavi= np.asarray(comb_msavi).astype(np.float64)
comb_nbr= np.asarray(comb_nbr).astype(np.float64)
comb_ndvi= np.asarray(comb_ndvi).astype(np.float64)

# %%
comb_stack = np.stack((comb_cbi, comb_bsi, comb_evi2,
                       comb_mndwi, comb_msavi, comb_nbr, 
                       comb_ndvi), axis=1)

# comb_stack = np.stack((comb_cbi, comb_bsi, comb_evi2), axis=1)
# print(comb_stack.shape)

comb_stack_reshape = comb_stack.reshape(comb_stack.shape[0], comb_stack.shape[2], comb_stack.shape[1])
print(comb_stack_reshape.shape)

X_train, X_test, y_train, y_test = train_test_split(comb_stack_reshape , y_cat, test_size=0.30, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1972, 39, 7)
# (1380, 39, 7) (1380, 7) (592, 39, 7) (592, 7)

# %%
# print(comb_cbi.shape)

# %%
# stack_ver = np.hstack((vert_cbi, vert_bsi, vert_evi2,
#                        vert_mndwi, vert_msavi, vert_nbr, 
#                        vert_ndvi))
# print(stack_ver.shape)

# %%
# import seaborn as sns 

# x = ['CBI','BSI','EVI2', 'MNDWI', 'MSAVI', 'NBR', 'NDVI']
# # enumerate label
# for i in enumerate(x):
#     print(i)

# # plot correlation matrix
# rf_pd = pd.DataFrame(data=stack_ver, columns=list(x))
# matrix = np.triu(rf_pd.corr())
# plt.figure(figsize=(12,8))
# sns.heatmap(rf_pd.corr(), annot=True, mask=matrix)

# %%
num_classes = len(np.unique(y))
input_shape=(X_train.shape[1], X_train.shape[2])
print(num_classes)
print(input_shape)
# Out:
# 7
# (39, 7)

# %%
def conv_bn(X, **conv_params):
    nbunits = conv_params["nbunits"];
    kernel_size = conv_params["kernel_size"];
    
    strides = conv_params.setdefault("strides", 1)
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-6))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    
    Z = Conv1D(nbunits, kernel_size=kernel_size, 
               strides = strides, padding=padding,
               kernel_initializer=kernel_initializer,
               kernel_regularizer=kernel_regularizer)(X)
    
    return BatchNormalization(axis=-1)(Z) #-- CHANNEL_AXIS (-1)

# %%
def fc_bn(X, **fc_params):
    nbunits = fc_params["nbunits"];
    kernel_regularizer = fc_params.setdefault("kernel_regularizer", l2(1.e-6))
    kernel_initializer = fc_params.setdefault("kernel_initializer", "he_normal")
    Z = Dense(nbunits, kernel_initializer=kernel_initializer, kernel_regularizer=kernel_regularizer)(X)
    
    return BatchNormalization(axis=-1)(Z) #-- CHANNEL_AXIS (-1)

# %%
def conv_bn_relu(X, **conv_params):
    Znorm = conv_bn(X, **conv_params)
    return Activation('relu')(Znorm)

# %%
def conv_bn_relu_drop(X, **conv_params):
    dropout_rate = conv_params.setdefault("dropout_rate", 0.5)
    A = conv_bn_relu(X, **conv_params)
    return Dropout(dropout_rate)(A)

# %%
def fc_bn_relu(X, **fc_params):
    Znorm = fc_bn(X, **fc_params)
    return Activation('relu')(Znorm)

# %%
def fc_bn_relu_drop(X, **fc_params):
    dropout_rate = fc_params.setdefault("dropout_rate", 0.5)
    A = fc_bn_relu(X, **fc_params)
    return Dropout(dropout_rate)(A)

# %%
def softmax(X, nbclasses, **params):
    kernel_regularizer = params.setdefault("kernel_regularizer", l2(1.e-6))
    kernel_initializer = params.setdefault("kernel_initializer", "glorot_uniform")
    return Dense(nbclasses, activation='softmax',
                 kernel_initializer=kernel_initializer,
                 kernel_regularizer=kernel_regularizer)(X)

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Metric

class CustomMeanIoU(Metric):
    def __init__(self, num_classes, name='custom_mean_iou', **kwargs):
        super(CustomMeanIoU, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.confusion_matrix = self.add_weight(
            'confusion_matrix',
            shape=(num_classes, num_classes),
            initializer='zeros',
            dtype=tf.float32)
            
    def update_state(self, y_true, y_pred, sample_weight=None):
        # First, ensure y_pred is class indices (argmax) and cast to int32
        if len(tf.shape(y_pred)) > 1 and tf.shape(y_pred)[-1] > 1:
            y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
        else:
            # If not one-hot, ensure it's still int32
            y_pred = tf.cast(y_pred, tf.int32)
        
        # Then ensure y_true is the same format (class indices as int32)
        if len(tf.shape(y_true)) > 1 and tf.shape(y_true)[-1] > 1:
            y_true = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)
        else:
            # If not one-hot, ensure it's still int32
            y_true = tf.cast(y_true, tf.int32)
            
        # Convert to 1D tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])
        
        # Calculate confusion matrix
        cm_update = tf.math.confusion_matrix(
            y_true, y_pred, self.num_classes, 
            dtype=tf.float32)
        
        # Update the total confusion matrix
        self.confusion_matrix.assign_add(cm_update)
        
    def result(self):
        cm = self.confusion_matrix
        
        # Extract per-class TP, FP, FN
        tp = tf.linalg.diag_part(cm)
        sum_over_row = tf.reduce_sum(cm, axis=1)
        sum_over_col = tf.reduce_sum(cm, axis=0)
        fp = sum_over_col - tp
        fn = sum_over_row - tp
        
        # Calculate IoU per class
        denominator = tp + fp + fn
        
        # Avoid division by zero
        iou = tf.math.divide_no_nan(tp, denominator)
        
        # Calculate mean IoU (average over classes)
        valid_classes = tf.cast(denominator > 0, tf.float32)
        num_valid = tf.reduce_sum(valid_classes)
        
        # Return mean IoU
        return tf.math.divide_no_nan(tf.reduce_sum(iou), num_valid)
        
    def reset_state(self):
        # Reset the confusion matrix at the start of each epoch
        self.confusion_matrix.assign(tf.zeros((self.num_classes, self.num_classes)))

    def get_config(self):
        config = super(CustomMeanIoU, self).get_config()
        config.update({"num_classes": self.num_classes})
        return config

# %%
# %%time

def make_model(X, num_classes):
    l2_rate = 0.000001
    dropout_rate = 0.5
    nb_rnn = 3
    nbunits_rnn = 128
    nbunits_fc = 256
    
    X_input = Input(input_shape)
    X = X_input
    for add in range(nb_rnn-1):
        X = Bidirectional(GRU(nbunits_rnn, return_sequences=True))(X)
        X = Dropout(dropout_rate)(X)
        X = Bidirectional(GRU(nbunits_rnn, return_sequences=False))(X)
        X = Dropout(dropout_rate)(X)
        #-- 1 FC layers
        
        X = fc_bn_relu_drop(X, nbunits=nbunits_fc, kernel_regularizer=l2(l2_rate), dropout_rate=dropout_rate)
        #-- SOFTMAX layer
        out = softmax(X, num_classes, kernel_regularizer=l2(l2_rate)) 
        # Create model
        
        return Model(inputs=X_input, outputs=out)

model = make_model(input_shape, num_classes)
model.summary()
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
              optimizer=optimizers.Adam(learning_rate=0.001), 
              metrics=[CustomMeanIoU(num_classes=7)])

checkpoint = ModelCheckpoint(filepath='D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model/LC_DAS_Citarum_exp03_TempCNN_mIoU.h5',
                              monitor='val_custom_mean_iou',save_best_only=True,verbose=1, mode='max')
early_stop = EarlyStopping(monitor='val_custom_mean_iou',patience=100,restore_best_weights=True,mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_custom_mean_iou', factor=0.1,patience=30, min_lr=0.00001)

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size =20,
                    epochs=500, callbacks = [checkpoint, early_stop, reduce_lr], 
                    class_weight=class_weights)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 39, 7)]           0
#
#  bidirectional (Bidirection  (None, 39, 256)           105216
#  al)
#
#  dropout (Dropout)           (None, 39, 256)           0
#
#  bidirectional_1 (Bidirecti  (None, 256)               296448
#  onal)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 470279 (1.79 MB)
# Trainable params: 469767 (1.79 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/500
# 69/69 [==============================] - ETA: 0s - loss: 1.7258 - custom_mean_iou: 0.1987
# Epoch 1: val_custom_mean_iou improved from -inf to 0.27495, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# D:\anaconda\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/69 [==============================] - 12s 91ms/step - loss: 1.7258 - custom_mean_iou: 0.1987 - val_loss: 1.5423 - val_custom_mean_iou: 0.2749 - lr: 0.0010
# Epoch 2/500
# 69/69 [==============================] - ETA: 0s - loss: 1.4832 - custom_mean_iou: 0.2701
# Epoch 2: val_custom_mean_iou improved from 0.27495 to 0.32320, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 68ms/step - loss: 1.4832 - custom_mean_iou: 0.2701 - val_loss: 1.2823 - val_custom_mean_iou: 0.3232 - lr: 0.0010
# Epoch 3/500
# 69/69 [==============================] - ETA: 0s - loss: 1.3689 - custom_mean_iou: 0.2998
# Epoch 3: val_custom_mean_iou improved from 0.32320 to 0.35566, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 66ms/step - loss: 1.3689 - custom_mean_iou: 0.2998 - val_loss: 1.1254 - val_custom_mean_iou: 0.3557 - lr: 0.0010
# Epoch 4/500
# 68/69 [============================>.] - ETA: 0s - loss: 1.2359 - custom_mean_iou: 0.3325
# Epoch 4: val_custom_mean_iou improved from 0.35566 to 0.45988, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 78ms/step - loss: 1.2357 - custom_mean_iou: 0.3348 - val_loss: 0.9026 - val_custom_mean_iou: 0.4599 - lr: 0.0010
# Epoch 5/500
# 69/69 [==============================] - ETA: 0s - loss: 1.1111 - custom_mean_iou: 0.3770
# Epoch 5: val_custom_mean_iou did not improve from 0.45988
# 69/69 [==============================] - 4s 65ms/step - loss: 1.1111 - custom_mean_iou: 0.3770 - val_loss: 0.9908 - val_custom_mean_iou: 0.4115 - lr: 0.0010
# Epoch 6/500
# 69/69 [==============================] - ETA: 0s - loss: 0.9376 - custom_mean_iou: 0.4678
# Epoch 6: val_custom_mean_iou improved from 0.45988 to 0.51413, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 70ms/step - loss: 0.9376 - custom_mean_iou: 0.4678 - val_loss: 0.7241 - val_custom_mean_iou: 0.5141 - lr: 0.0010
# Epoch 7/500
# 69/69 [==============================] - ETA: 0s - loss: 0.9018 - custom_mean_iou: 0.4887
# Epoch 7: val_custom_mean_iou did not improve from 0.51413
# 69/69 [==============================] - 5s 76ms/step - loss: 0.9018 - custom_mean_iou: 0.4887 - val_loss: 1.6012 - val_custom_mean_iou: 0.3080 - lr: 0.0010
# Epoch 8/500
# 69/69 [==============================] - ETA: 0s - loss: 0.8028 - custom_mean_iou: 0.5397
# Epoch 8: val_custom_mean_iou did not improve from 0.51413
# 69/69 [==============================] - 5s 78ms/step - loss: 0.8028 - custom_mean_iou: 0.5397 - val_loss: 1.1189 - val_custom_mean_iou: 0.4424 - lr: 0.0010
# Epoch 9/500
# 69/69 [==============================] - ETA: 0s - loss: 0.7706 - custom_mean_iou: 0.5545
# Epoch 9: val_custom_mean_iou improved from 0.51413 to 0.52673, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 79ms/step - loss: 0.7706 - custom_mean_iou: 0.5545 - val_loss: 0.8483 - val_custom_mean_iou: 0.5267 - lr: 0.0010
# Epoch 10/500
# 69/69 [==============================] - ETA: 0s - loss: 0.7172 - custom_mean_iou: 0.5717
# Epoch 10: val_custom_mean_iou improved from 0.52673 to 0.58138, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 79ms/step - loss: 0.7172 - custom_mean_iou: 0.5717 - val_loss: 0.6453 - val_custom_mean_iou: 0.5814 - lr: 0.0010
# Epoch 11/500
# 69/69 [==============================] - ETA: 0s - loss: 0.6491 - custom_mean_iou: 0.5864
# Epoch 11: val_custom_mean_iou improved from 0.58138 to 0.65649, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 76ms/step - loss: 0.6491 - custom_mean_iou: 0.5864 - val_loss: 0.5329 - val_custom_mean_iou: 0.6565 - lr: 0.0010
# Epoch 12/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5856 - custom_mean_iou: 0.6485
# Epoch 12: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 73ms/step - loss: 0.5856 - custom_mean_iou: 0.6485 - val_loss: 0.5453 - val_custom_mean_iou: 0.6410 - lr: 0.0010
# Epoch 13/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5668 - custom_mean_iou: 0.6631
# Epoch 13: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 74ms/step - loss: 0.5668 - custom_mean_iou: 0.6631 - val_loss: 0.4969 - val_custom_mean_iou: 0.6540 - lr: 0.0010
# Epoch 14/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5620 - custom_mean_iou: 0.6416
# Epoch 14: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 74ms/step - loss: 0.5620 - custom_mean_iou: 0.6416 - val_loss: 0.6187 - val_custom_mean_iou: 0.6096 - lr: 0.0010
# Epoch 15/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5600 - custom_mean_iou: 0.6307
# Epoch 15: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 75ms/step - loss: 0.5600 - custom_mean_iou: 0.6307 - val_loss: 0.9233 - val_custom_mean_iou: 0.5603 - lr: 0.0010
# Epoch 16/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5563 - custom_mean_iou: 0.6592
# Epoch 16: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 74ms/step - loss: 0.5563 - custom_mean_iou: 0.6592 - val_loss: 1.3227 - val_custom_mean_iou: 0.3793 - lr: 0.0010
# Epoch 17/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5066 - custom_mean_iou: 0.6754
# Epoch 17: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 74ms/step - loss: 0.5066 - custom_mean_iou: 0.6754 - val_loss: 0.6551 - val_custom_mean_iou: 0.5857 - lr: 0.0010
# Epoch 18/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5001 - custom_mean_iou: 0.6692
# Epoch 18: val_custom_mean_iou did not improve from 0.65649
# 69/69 [==============================] - 5s 74ms/step - loss: 0.5001 - custom_mean_iou: 0.6692 - val_loss: 2.9813 - val_custom_mean_iou: 0.1687 - lr: 0.0010
# Epoch 19/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5247 - custom_mean_iou: 0.6639
# Epoch 19: val_custom_mean_iou improved from 0.65649 to 0.68004, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 6s 89ms/step - loss: 0.5247 - custom_mean_iou: 0.6639 - val_loss: 0.4956 - val_custom_mean_iou: 0.6800 - lr: 0.0010
# Epoch 20/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4637 - custom_mean_iou: 0.7084
# Epoch 20: val_custom_mean_iou improved from 0.68004 to 0.70253, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 77ms/step - loss: 0.4637 - custom_mean_iou: 0.7084 - val_loss: 0.4227 - val_custom_mean_iou: 0.7025 - lr: 0.0010
# Epoch 21/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4472 - custom_mean_iou: 0.7084
# Epoch 21: val_custom_mean_iou did not improve from 0.70253
# 69/69 [==============================] - 5s 74ms/step - loss: 0.4472 - custom_mean_iou: 0.7084 - val_loss: 0.4353 - val_custom_mean_iou: 0.6925 - lr: 0.0010
# Epoch 22/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4724 - custom_mean_iou: 0.6994
# Epoch 22: val_custom_mean_iou did not improve from 0.70253
# 69/69 [==============================] - 5s 75ms/step - loss: 0.4724 - custom_mean_iou: 0.6994 - val_loss: 0.4499 - val_custom_mean_iou: 0.6814 - lr: 0.0010
# Epoch 23/500
# 69/69 [==============================] - ETA: 0s - loss: 0.5322 - custom_mean_iou: 0.6683
# Epoch 23: val_custom_mean_iou did not improve from 0.70253
# 69/69 [==============================] - 5s 75ms/step - loss: 0.5322 - custom_mean_iou: 0.6683 - val_loss: 0.5607 - val_custom_mean_iou: 0.6772 - lr: 0.0010
# Epoch 24/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4283 - custom_mean_iou: 0.7208
# Epoch 24: val_custom_mean_iou improved from 0.70253 to 0.74615, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 76ms/step - loss: 0.4283 - custom_mean_iou: 0.7208 - val_loss: 0.3336 - val_custom_mean_iou: 0.7461 - lr: 0.0010
# Epoch 25/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4459 - custom_mean_iou: 0.7036
# Epoch 25: val_custom_mean_iou did not improve from 0.74615
# 69/69 [==============================] - 5s 72ms/step - loss: 0.4459 - custom_mean_iou: 0.7036 - val_loss: 0.5020 - val_custom_mean_iou: 0.6497 - lr: 0.0010
# Epoch 26/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3972 - custom_mean_iou: 0.7469
# Epoch 26: val_custom_mean_iou improved from 0.74615 to 0.75215, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 6s 83ms/step - loss: 0.3972 - custom_mean_iou: 0.7469 - val_loss: 0.3439 - val_custom_mean_iou: 0.7522 - lr: 0.0010
# Epoch 27/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.3716 - custom_mean_iou: 0.7348
# Epoch 27: val_custom_mean_iou did not improve from 0.75215
# 69/69 [==============================] - 5s 68ms/step - loss: 0.3737 - custom_mean_iou: 0.7345 - val_loss: 0.6343 - val_custom_mean_iou: 0.6178 - lr: 0.0010
# Epoch 28/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4103 - custom_mean_iou: 0.7470
# Epoch 28: val_custom_mean_iou improved from 0.75215 to 0.75868, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 75ms/step - loss: 0.4103 - custom_mean_iou: 0.7470 - val_loss: 0.2976 - val_custom_mean_iou: 0.7587 - lr: 0.0010
# Epoch 29/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4161 - custom_mean_iou: 0.7405
# Epoch 29: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 67ms/step - loss: 0.4161 - custom_mean_iou: 0.7405 - val_loss: 0.5953 - val_custom_mean_iou: 0.6211 - lr: 0.0010
# Epoch 30/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.3929 - custom_mean_iou: 0.7208
# Epoch 30: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 70ms/step - loss: 0.3931 - custom_mean_iou: 0.7207 - val_loss: 0.3482 - val_custom_mean_iou: 0.7534 - lr: 0.0010
# Epoch 31/500
# 69/69 [==============================] - ETA: 0s - loss: 0.4089 - custom_mean_iou: 0.7218
# Epoch 31: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 67ms/step - loss: 0.4089 - custom_mean_iou: 0.7218 - val_loss: 0.3395 - val_custom_mean_iou: 0.7545 - lr: 0.0010
# Epoch 32/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3500 - custom_mean_iou: 0.7664
# Epoch 32: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 71ms/step - loss: 0.3500 - custom_mean_iou: 0.7664 - val_loss: 0.3293 - val_custom_mean_iou: 0.7527 - lr: 0.0010
# Epoch 33/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3456 - custom_mean_iou: 0.7562
# Epoch 33: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 69ms/step - loss: 0.3456 - custom_mean_iou: 0.7562 - val_loss: 0.5328 - val_custom_mean_iou: 0.6573 - lr: 0.0010
# Epoch 34/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3761 - custom_mean_iou: 0.7333
# Epoch 34: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 70ms/step - loss: 0.3761 - custom_mean_iou: 0.7333 - val_loss: 0.4716 - val_custom_mean_iou: 0.6606 - lr: 0.0010
# Epoch 35/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3698 - custom_mean_iou: 0.7375
# Epoch 35: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 72ms/step - loss: 0.3698 - custom_mean_iou: 0.7375 - val_loss: 0.8281 - val_custom_mean_iou: 0.5747 - lr: 0.0010
# Epoch 36/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3499 - custom_mean_iou: 0.7542
# Epoch 36: val_custom_mean_iou did not improve from 0.75868
# 69/69 [==============================] - 5s 74ms/step - loss: 0.3499 - custom_mean_iou: 0.7542 - val_loss: 0.3875 - val_custom_mean_iou: 0.7107 - lr: 0.0010
# Epoch 37/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3468 - custom_mean_iou: 0.7523
# Epoch 37: val_custom_mean_iou improved from 0.75868 to 0.77136, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 7s 102ms/step - loss: 0.3468 - custom_mean_iou: 0.7523 - val_loss: 0.3264 - val_custom_mean_iou: 0.7714 - lr: 0.0010
# Epoch 38/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3665 - custom_mean_iou: 0.7596
# Epoch 38: val_custom_mean_iou improved from 0.77136 to 0.79661, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 6s 86ms/step - loss: 0.3665 - custom_mean_iou: 0.7596 - val_loss: 0.2897 - val_custom_mean_iou: 0.7966 - lr: 0.0010
# Epoch 39/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3494 - custom_mean_iou: 0.7542
# Epoch 39: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 75ms/step - loss: 0.3494 - custom_mean_iou: 0.7542 - val_loss: 0.5829 - val_custom_mean_iou: 0.6500 - lr: 0.0010
# Epoch 40/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.3250 - custom_mean_iou: 0.7645
# Epoch 40: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 69ms/step - loss: 0.3261 - custom_mean_iou: 0.7631 - val_loss: 0.4282 - val_custom_mean_iou: 0.7000 - lr: 0.0010
# Epoch 41/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3187 - custom_mean_iou: 0.7721
# Epoch 41: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 69ms/step - loss: 0.3187 - custom_mean_iou: 0.7721 - val_loss: 0.3993 - val_custom_mean_iou: 0.7070 - lr: 0.0010
# Epoch 42/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3294 - custom_mean_iou: 0.7596
# Epoch 42: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 67ms/step - loss: 0.3294 - custom_mean_iou: 0.7596 - val_loss: 0.3380 - val_custom_mean_iou: 0.7658 - lr: 0.0010
# Epoch 43/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3461 - custom_mean_iou: 0.7754
# Epoch 43: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 68ms/step - loss: 0.3461 - custom_mean_iou: 0.7754 - val_loss: 0.4483 - val_custom_mean_iou: 0.7154 - lr: 0.0010
# Epoch 44/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3245 - custom_mean_iou: 0.7783
# Epoch 44: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 68ms/step - loss: 0.3245 - custom_mean_iou: 0.7783 - val_loss: 0.4371 - val_custom_mean_iou: 0.7019 - lr: 0.0010
# Epoch 45/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2864 - custom_mean_iou: 0.7775
# Epoch 45: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 68ms/step - loss: 0.2864 - custom_mean_iou: 0.7775 - val_loss: 0.3157 - val_custom_mean_iou: 0.7821 - lr: 0.0010
# Epoch 46/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2868 - custom_mean_iou: 0.7880
# Epoch 46: val_custom_mean_iou did not improve from 0.79661
# 69/69 [==============================] - 5s 68ms/step - loss: 0.2868 - custom_mean_iou: 0.7880 - val_loss: 0.3643 - val_custom_mean_iou: 0.7621 - lr: 0.0010
# Epoch 47/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2438 - custom_mean_iou: 0.8108
# Epoch 47: val_custom_mean_iou improved from 0.79661 to 0.83280, saving model to D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model\LC_DAS_Citarum_exp03_TempCNN_mIoU.h5
# 69/69 [==============================] - 5s 77ms/step - loss: 0.2438 - custom_mean_iou: 0.8108 - val_loss: 0.2276 - val_custom_mean_iou: 0.8328 - lr: 0.0010
# Epoch 48/500
# 69/69 [==============================] - ETA: 0s - loss: 0.3263 - custom_mean_iou: 0.7782
# Epoch 48: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 6s 83ms/step - loss: 0.3263 - custom_mean_iou: 0.7782 - val_loss: 0.4309 - val_custom_mean_iou: 0.7163 - lr: 0.0010
# Epoch 49/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2659 - custom_mean_iou: 0.8056
# Epoch 49: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 6s 82ms/step - loss: 0.2659 - custom_mean_iou: 0.8056 - val_loss: 0.2684 - val_custom_mean_iou: 0.8057 - lr: 1.0000e-04
# Epoch 50/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2259 - custom_mean_iou: 0.8235
# Epoch 50: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.2259 - custom_mean_iou: 0.8235 - val_loss: 0.2307 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-04
# Epoch 51/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2279 - custom_mean_iou: 0.8287
# Epoch 51: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.2279 - custom_mean_iou: 0.8287 - val_loss: 0.2537 - val_custom_mean_iou: 0.7970 - lr: 1.0000e-04
# Epoch 52/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2354 - custom_mean_iou: 0.8302
# Epoch 52: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 67ms/step - loss: 0.2354 - custom_mean_iou: 0.8302 - val_loss: 0.2553 - val_custom_mean_iou: 0.8035 - lr: 1.0000e-04
# Epoch 53/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2252 - custom_mean_iou: 0.8372
# Epoch 53: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.2252 - custom_mean_iou: 0.8372 - val_loss: 0.2359 - val_custom_mean_iou: 0.8113 - lr: 1.0000e-04
# Epoch 54/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2095 - custom_mean_iou: 0.8528
# Epoch 54: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 67ms/step - loss: 0.2095 - custom_mean_iou: 0.8528 - val_loss: 0.2499 - val_custom_mean_iou: 0.7985 - lr: 1.0000e-04
# Epoch 55/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.2124 - custom_mean_iou: 0.8439
# Epoch 55: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 67ms/step - loss: 0.2206 - custom_mean_iou: 0.8402 - val_loss: 0.2397 - val_custom_mean_iou: 0.8041 - lr: 1.0000e-04
# Epoch 56/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2238 - custom_mean_iou: 0.8429
# Epoch 56: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.2238 - custom_mean_iou: 0.8429 - val_loss: 0.2228 - val_custom_mean_iou: 0.8189 - lr: 1.0000e-04
# Epoch 57/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2154 - custom_mean_iou: 0.8352
# Epoch 57: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 77ms/step - loss: 0.2154 - custom_mean_iou: 0.8352 - val_loss: 0.2265 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-04
# Epoch 58/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2134 - custom_mean_iou: 0.8376
# Epoch 58: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 6s 84ms/step - loss: 0.2134 - custom_mean_iou: 0.8376 - val_loss: 0.2353 - val_custom_mean_iou: 0.8155 - lr: 1.0000e-04
# Epoch 59/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2119 - custom_mean_iou: 0.8412
# Epoch 59: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 80ms/step - loss: 0.2119 - custom_mean_iou: 0.8412 - val_loss: 0.2536 - val_custom_mean_iou: 0.8062 - lr: 1.0000e-04
# Epoch 60/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2043 - custom_mean_iou: 0.8267
# Epoch 60: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 75ms/step - loss: 0.2043 - custom_mean_iou: 0.8267 - val_loss: 0.2170 - val_custom_mean_iou: 0.8229 - lr: 1.0000e-04
# Epoch 61/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1881 - custom_mean_iou: 0.8442
# Epoch 61: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 6s 81ms/step - loss: 0.1881 - custom_mean_iou: 0.8442 - val_loss: 0.2701 - val_custom_mean_iou: 0.7937 - lr: 1.0000e-04
# Epoch 62/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2054 - custom_mean_iou: 0.8423
# Epoch 62: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.2054 - custom_mean_iou: 0.8423 - val_loss: 0.2551 - val_custom_mean_iou: 0.7942 - lr: 1.0000e-04
# Epoch 63/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1905 - custom_mean_iou: 0.8545
# Epoch 63: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1905 - custom_mean_iou: 0.8545 - val_loss: 0.2268 - val_custom_mean_iou: 0.8167 - lr: 1.0000e-04
# Epoch 64/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2017 - custom_mean_iou: 0.8619
# Epoch 64: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 78ms/step - loss: 0.2017 - custom_mean_iou: 0.8619 - val_loss: 0.2327 - val_custom_mean_iou: 0.8076 - lr: 1.0000e-04
# Epoch 65/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2005 - custom_mean_iou: 0.8403
# Epoch 65: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 79ms/step - loss: 0.2005 - custom_mean_iou: 0.8403 - val_loss: 0.2271 - val_custom_mean_iou: 0.8207 - lr: 1.0000e-04
# Epoch 66/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1805 - custom_mean_iou: 0.8701
# Epoch 66: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1805 - custom_mean_iou: 0.8701 - val_loss: 0.2240 - val_custom_mean_iou: 0.8207 - lr: 1.0000e-04
# Epoch 67/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1923 - custom_mean_iou: 0.8570
# Epoch 67: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1923 - custom_mean_iou: 0.8570 - val_loss: 0.2293 - val_custom_mean_iou: 0.8169 - lr: 1.0000e-04
# Epoch 68/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1830 - custom_mean_iou: 0.8500
# Epoch 68: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1830 - custom_mean_iou: 0.8500 - val_loss: 0.2379 - val_custom_mean_iou: 0.8179 - lr: 1.0000e-04
# Epoch 69/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1916 - custom_mean_iou: 0.8517
# Epoch 69: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1916 - custom_mean_iou: 0.8517 - val_loss: 0.2398 - val_custom_mean_iou: 0.8061 - lr: 1.0000e-04
# Epoch 70/500
# 69/69 [==============================] - ETA: 0s - loss: 0.2068 - custom_mean_iou: 0.8235
# Epoch 70: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 73ms/step - loss: 0.2068 - custom_mean_iou: 0.8235 - val_loss: 0.2348 - val_custom_mean_iou: 0.8044 - lr: 1.0000e-04
# Epoch 71/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1731 - custom_mean_iou: 0.8638
# Epoch 71: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1731 - custom_mean_iou: 0.8638 - val_loss: 0.2537 - val_custom_mean_iou: 0.8118 - lr: 1.0000e-04
# Epoch 72/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1630 - custom_mean_iou: 0.8672
# Epoch 72: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 72ms/step - loss: 0.1630 - custom_mean_iou: 0.8672 - val_loss: 0.2303 - val_custom_mean_iou: 0.8056 - lr: 1.0000e-04
# Epoch 73/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1919 - custom_mean_iou: 0.8422
# Epoch 73: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 67ms/step - loss: 0.1919 - custom_mean_iou: 0.8422 - val_loss: 0.2397 - val_custom_mean_iou: 0.8035 - lr: 1.0000e-04
# Epoch 74/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1856 - custom_mean_iou: 0.8629
# Epoch 74: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1856 - custom_mean_iou: 0.8629 - val_loss: 0.2178 - val_custom_mean_iou: 0.8237 - lr: 1.0000e-04
# Epoch 75/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1919 - custom_mean_iou: 0.8486
# Epoch 75: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.2040 - custom_mean_iou: 0.8436 - val_loss: 0.2390 - val_custom_mean_iou: 0.8107 - lr: 1.0000e-04
# Epoch 76/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1779 - custom_mean_iou: 0.8663
# Epoch 76: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1779 - custom_mean_iou: 0.8663 - val_loss: 0.2194 - val_custom_mean_iou: 0.8232 - lr: 1.0000e-04
# Epoch 77/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1624 - custom_mean_iou: 0.8666
# Epoch 77: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1624 - custom_mean_iou: 0.8666 - val_loss: 0.2168 - val_custom_mean_iou: 0.8159 - lr: 1.0000e-04
# Epoch 78/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1661 - custom_mean_iou: 0.8692
# Epoch 78: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1649 - custom_mean_iou: 0.8705 - val_loss: 0.2314 - val_custom_mean_iou: 0.8145 - lr: 1.0000e-04
# Epoch 79/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1716 - custom_mean_iou: 0.8645
# Epoch 79: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1716 - custom_mean_iou: 0.8645 - val_loss: 0.2291 - val_custom_mean_iou: 0.8163 - lr: 1.0000e-05
# Epoch 80/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1584 - custom_mean_iou: 0.8697
# Epoch 80: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1584 - custom_mean_iou: 0.8697 - val_loss: 0.2265 - val_custom_mean_iou: 0.8260 - lr: 1.0000e-05
# Epoch 81/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1802 - custom_mean_iou: 0.8589
# Epoch 81: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1787 - custom_mean_iou: 0.8597 - val_loss: 0.2263 - val_custom_mean_iou: 0.8219 - lr: 1.0000e-05
# Epoch 82/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1621 - custom_mean_iou: 0.8731
# Epoch 82: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1621 - custom_mean_iou: 0.8731 - val_loss: 0.2286 - val_custom_mean_iou: 0.8209 - lr: 1.0000e-05
# Epoch 83/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1729 - custom_mean_iou: 0.8535
# Epoch 83: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1729 - custom_mean_iou: 0.8535 - val_loss: 0.2283 - val_custom_mean_iou: 0.8178 - lr: 1.0000e-05
# Epoch 84/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1608 - custom_mean_iou: 0.8675
# Epoch 84: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1608 - custom_mean_iou: 0.8675 - val_loss: 0.2281 - val_custom_mean_iou: 0.8199 - lr: 1.0000e-05
# Epoch 85/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1689 - custom_mean_iou: 0.8634
# Epoch 85: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1689 - custom_mean_iou: 0.8634 - val_loss: 0.2277 - val_custom_mean_iou: 0.8178 - lr: 1.0000e-05
# Epoch 86/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1736 - custom_mean_iou: 0.8679
# Epoch 86: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1736 - custom_mean_iou: 0.8679 - val_loss: 0.2295 - val_custom_mean_iou: 0.8149 - lr: 1.0000e-05
# Epoch 87/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1701 - custom_mean_iou: 0.8691
# Epoch 87: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1701 - custom_mean_iou: 0.8691 - val_loss: 0.2288 - val_custom_mean_iou: 0.8149 - lr: 1.0000e-05
# Epoch 88/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1700 - custom_mean_iou: 0.8561
# Epoch 88: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1700 - custom_mean_iou: 0.8561 - val_loss: 0.2262 - val_custom_mean_iou: 0.8253 - lr: 1.0000e-05
# Epoch 89/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1639 - custom_mean_iou: 0.8604
# Epoch 89: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1639 - custom_mean_iou: 0.8604 - val_loss: 0.2243 - val_custom_mean_iou: 0.8193 - lr: 1.0000e-05
# Epoch 90/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1703 - custom_mean_iou: 0.8627
# Epoch 90: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1703 - custom_mean_iou: 0.8627 - val_loss: 0.2246 - val_custom_mean_iou: 0.8127 - lr: 1.0000e-05
# Epoch 91/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1677 - custom_mean_iou: 0.8628
# Epoch 91: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1677 - custom_mean_iou: 0.8628 - val_loss: 0.2269 - val_custom_mean_iou: 0.8127 - lr: 1.0000e-05
# Epoch 92/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1704 - custom_mean_iou: 0.8702
# Epoch 92: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1704 - custom_mean_iou: 0.8702 - val_loss: 0.2252 - val_custom_mean_iou: 0.8226 - lr: 1.0000e-05
# Epoch 93/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1577 - custom_mean_iou: 0.8644
# Epoch 93: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1577 - custom_mean_iou: 0.8644 - val_loss: 0.2248 - val_custom_mean_iou: 0.8234 - lr: 1.0000e-05
# Epoch 94/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1673 - custom_mean_iou: 0.8773
# Epoch 94: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1673 - custom_mean_iou: 0.8773 - val_loss: 0.2257 - val_custom_mean_iou: 0.8196 - lr: 1.0000e-05
# Epoch 95/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1636 - custom_mean_iou: 0.8612
# Epoch 95: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1636 - custom_mean_iou: 0.8612 - val_loss: 0.2254 - val_custom_mean_iou: 0.8148 - lr: 1.0000e-05
# Epoch 96/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1762 - custom_mean_iou: 0.8652
# Epoch 96: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1762 - custom_mean_iou: 0.8652 - val_loss: 0.2276 - val_custom_mean_iou: 0.8226 - lr: 1.0000e-05
# Epoch 97/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1629 - custom_mean_iou: 0.8830
# Epoch 97: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1629 - custom_mean_iou: 0.8830 - val_loss: 0.2293 - val_custom_mean_iou: 0.8175 - lr: 1.0000e-05
# Epoch 98/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1699 - custom_mean_iou: 0.8603
# Epoch 98: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1699 - custom_mean_iou: 0.8603 - val_loss: 0.2277 - val_custom_mean_iou: 0.8135 - lr: 1.0000e-05
# Epoch 99/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1567 - custom_mean_iou: 0.8650
# Epoch 99: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1567 - custom_mean_iou: 0.8650 - val_loss: 0.2282 - val_custom_mean_iou: 0.8159 - lr: 1.0000e-05
# Epoch 100/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1478 - custom_mean_iou: 0.8880
# Epoch 100: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 6s 91ms/step - loss: 0.1478 - custom_mean_iou: 0.8880 - val_loss: 0.2271 - val_custom_mean_iou: 0.8187 - lr: 1.0000e-05
# Epoch 101/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1730 - custom_mean_iou: 0.8689
# Epoch 101: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 6s 83ms/step - loss: 0.1730 - custom_mean_iou: 0.8689 - val_loss: 0.2271 - val_custom_mean_iou: 0.8214 - lr: 1.0000e-05
# Epoch 102/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1726 - custom_mean_iou: 0.8618
# Epoch 102: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1717 - custom_mean_iou: 0.8624 - val_loss: 0.2299 - val_custom_mean_iou: 0.8157 - lr: 1.0000e-05
# Epoch 103/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1569 - custom_mean_iou: 0.8680
# Epoch 103: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1569 - custom_mean_iou: 0.8680 - val_loss: 0.2275 - val_custom_mean_iou: 0.8187 - lr: 1.0000e-05
# Epoch 104/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1791 - custom_mean_iou: 0.8546
# Epoch 104: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1791 - custom_mean_iou: 0.8546 - val_loss: 0.2277 - val_custom_mean_iou: 0.8159 - lr: 1.0000e-05
# Epoch 105/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1654 - custom_mean_iou: 0.8618
# Epoch 105: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1654 - custom_mean_iou: 0.8618 - val_loss: 0.2295 - val_custom_mean_iou: 0.8180 - lr: 1.0000e-05
# Epoch 106/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1609 - custom_mean_iou: 0.8809
# Epoch 106: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1609 - custom_mean_iou: 0.8809 - val_loss: 0.2296 - val_custom_mean_iou: 0.8196 - lr: 1.0000e-05
# Epoch 107/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1628 - custom_mean_iou: 0.8765
# Epoch 107: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1628 - custom_mean_iou: 0.8765 - val_loss: 0.2270 - val_custom_mean_iou: 0.8260 - lr: 1.0000e-05
# Epoch 108/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1604 - custom_mean_iou: 0.8616
# Epoch 108: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1604 - custom_mean_iou: 0.8616 - val_loss: 0.2252 - val_custom_mean_iou: 0.8156 - lr: 1.0000e-05
# Epoch 109/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1811 - custom_mean_iou: 0.8441
# Epoch 109: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1839 - custom_mean_iou: 0.8420 - val_loss: 0.2246 - val_custom_mean_iou: 0.8267 - lr: 1.0000e-05
# Epoch 110/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1590 - custom_mean_iou: 0.8768
# Epoch 110: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1585 - custom_mean_iou: 0.8770 - val_loss: 0.2281 - val_custom_mean_iou: 0.8223 - lr: 1.0000e-05
# Epoch 111/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1782 - custom_mean_iou: 0.8671
# Epoch 111: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1782 - custom_mean_iou: 0.8671 - val_loss: 0.2269 - val_custom_mean_iou: 0.8158 - lr: 1.0000e-05
# Epoch 112/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1592 - custom_mean_iou: 0.8684
# Epoch 112: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1592 - custom_mean_iou: 0.8684 - val_loss: 0.2254 - val_custom_mean_iou: 0.8081 - lr: 1.0000e-05
# Epoch 113/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1479 - custom_mean_iou: 0.8785
# Epoch 113: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1479 - custom_mean_iou: 0.8785 - val_loss: 0.2239 - val_custom_mean_iou: 0.8081 - lr: 1.0000e-05
# Epoch 114/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1701 - custom_mean_iou: 0.8734
# Epoch 114: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1701 - custom_mean_iou: 0.8734 - val_loss: 0.2243 - val_custom_mean_iou: 0.8187 - lr: 1.0000e-05
# Epoch 115/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1724 - custom_mean_iou: 0.8561
# Epoch 115: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1724 - custom_mean_iou: 0.8561 - val_loss: 0.2244 - val_custom_mean_iou: 0.8196 - lr: 1.0000e-05
# Epoch 116/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1607 - custom_mean_iou: 0.8680
# Epoch 116: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1607 - custom_mean_iou: 0.8680 - val_loss: 0.2279 - val_custom_mean_iou: 0.8196 - lr: 1.0000e-05
# Epoch 117/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1667 - custom_mean_iou: 0.8716
# Epoch 117: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1667 - custom_mean_iou: 0.8716 - val_loss: 0.2269 - val_custom_mean_iou: 0.8196 - lr: 1.0000e-05
# Epoch 118/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1632 - custom_mean_iou: 0.8625
# Epoch 118: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1632 - custom_mean_iou: 0.8625 - val_loss: 0.2299 - val_custom_mean_iou: 0.8167 - lr: 1.0000e-05
# Epoch 119/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1558 - custom_mean_iou: 0.8727
# Epoch 119: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1558 - custom_mean_iou: 0.8727 - val_loss: 0.2256 - val_custom_mean_iou: 0.8149 - lr: 1.0000e-05
# Epoch 120/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1668 - custom_mean_iou: 0.8611
# Epoch 120: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1668 - custom_mean_iou: 0.8611 - val_loss: 0.2263 - val_custom_mean_iou: 0.8151 - lr: 1.0000e-05
# Epoch 121/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1540 - custom_mean_iou: 0.8768
# Epoch 121: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1534 - custom_mean_iou: 0.8762 - val_loss: 0.2253 - val_custom_mean_iou: 0.8146 - lr: 1.0000e-05
# Epoch 122/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1500 - custom_mean_iou: 0.8772
# Epoch 122: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1485 - custom_mean_iou: 0.8792 - val_loss: 0.2253 - val_custom_mean_iou: 0.8151 - lr: 1.0000e-05
# Epoch 123/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1450 - custom_mean_iou: 0.8757
# Epoch 123: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1450 - custom_mean_iou: 0.8757 - val_loss: 0.2221 - val_custom_mean_iou: 0.8081 - lr: 1.0000e-05
# Epoch 124/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1523 - custom_mean_iou: 0.8836
# Epoch 124: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1523 - custom_mean_iou: 0.8836 - val_loss: 0.2256 - val_custom_mean_iou: 0.8262 - lr: 1.0000e-05
# Epoch 125/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1485 - custom_mean_iou: 0.8784
# Epoch 125: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1485 - custom_mean_iou: 0.8784 - val_loss: 0.2240 - val_custom_mean_iou: 0.8151 - lr: 1.0000e-05
# Epoch 126/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1743 - custom_mean_iou: 0.8625
# Epoch 126: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1726 - custom_mean_iou: 0.8631 - val_loss: 0.2246 - val_custom_mean_iou: 0.8233 - lr: 1.0000e-05
# Epoch 127/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1509 - custom_mean_iou: 0.8861
# Epoch 127: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1509 - custom_mean_iou: 0.8861 - val_loss: 0.2265 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-05
# Epoch 128/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1705 - custom_mean_iou: 0.8679
# Epoch 128: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1705 - custom_mean_iou: 0.8679 - val_loss: 0.2259 - val_custom_mean_iou: 0.8233 - lr: 1.0000e-05
# Epoch 129/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1972 - custom_mean_iou: 0.8475
# Epoch 129: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1972 - custom_mean_iou: 0.8475 - val_loss: 0.2322 - val_custom_mean_iou: 0.8224 - lr: 1.0000e-05
# Epoch 130/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1622 - custom_mean_iou: 0.8754
# Epoch 130: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1622 - custom_mean_iou: 0.8754 - val_loss: 0.2270 - val_custom_mean_iou: 0.8222 - lr: 1.0000e-05
# Epoch 131/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1827 - custom_mean_iou: 0.8582
# Epoch 131: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1827 - custom_mean_iou: 0.8582 - val_loss: 0.2302 - val_custom_mean_iou: 0.8211 - lr: 1.0000e-05
# Epoch 132/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1682 - custom_mean_iou: 0.8705
# Epoch 132: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1682 - custom_mean_iou: 0.8705 - val_loss: 0.2316 - val_custom_mean_iou: 0.8211 - lr: 1.0000e-05
# Epoch 133/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1606 - custom_mean_iou: 0.8763
# Epoch 133: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1606 - custom_mean_iou: 0.8763 - val_loss: 0.2235 - val_custom_mean_iou: 0.8233 - lr: 1.0000e-05
# Epoch 134/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1599 - custom_mean_iou: 0.8647
# Epoch 134: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 72ms/step - loss: 0.1599 - custom_mean_iou: 0.8647 - val_loss: 0.2269 - val_custom_mean_iou: 0.8206 - lr: 1.0000e-05
# Epoch 135/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1566 - custom_mean_iou: 0.8789
# Epoch 135: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 72ms/step - loss: 0.1566 - custom_mean_iou: 0.8789 - val_loss: 0.2281 - val_custom_mean_iou: 0.8262 - lr: 1.0000e-05
# Epoch 136/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1515 - custom_mean_iou: 0.8646
# Epoch 136: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1515 - custom_mean_iou: 0.8646 - val_loss: 0.2247 - val_custom_mean_iou: 0.8233 - lr: 1.0000e-05
# Epoch 137/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1580 - custom_mean_iou: 0.8767
# Epoch 137: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1580 - custom_mean_iou: 0.8767 - val_loss: 0.2248 - val_custom_mean_iou: 0.8233 - lr: 1.0000e-05
# Epoch 138/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1480 - custom_mean_iou: 0.8808
# Epoch 138: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1480 - custom_mean_iou: 0.8808 - val_loss: 0.2264 - val_custom_mean_iou: 0.8265 - lr: 1.0000e-05
# Epoch 139/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1639 - custom_mean_iou: 0.8853
# Epoch 139: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1639 - custom_mean_iou: 0.8853 - val_loss: 0.2274 - val_custom_mean_iou: 0.8238 - lr: 1.0000e-05
# Epoch 140/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1526 - custom_mean_iou: 0.8667
# Epoch 140: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1526 - custom_mean_iou: 0.8667 - val_loss: 0.2263 - val_custom_mean_iou: 0.8265 - lr: 1.0000e-05
# Epoch 141/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1611 - custom_mean_iou: 0.8729
# Epoch 141: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1611 - custom_mean_iou: 0.8729 - val_loss: 0.2248 - val_custom_mean_iou: 0.8247 - lr: 1.0000e-05
# Epoch 142/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1464 - custom_mean_iou: 0.8789
# Epoch 142: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1464 - custom_mean_iou: 0.8789 - val_loss: 0.2266 - val_custom_mean_iou: 0.8272 - lr: 1.0000e-05
# Epoch 143/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1633 - custom_mean_iou: 0.8800
# Epoch 143: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1613 - custom_mean_iou: 0.8814 - val_loss: 0.2288 - val_custom_mean_iou: 0.8215 - lr: 1.0000e-05
# Epoch 144/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1516 - custom_mean_iou: 0.8721
# Epoch 144: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1516 - custom_mean_iou: 0.8721 - val_loss: 0.2311 - val_custom_mean_iou: 0.8244 - lr: 1.0000e-05
# Epoch 145/500
# 68/69 [============================>.] - ETA: 0s - loss: 0.1544 - custom_mean_iou: 0.8719
# Epoch 145: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1536 - custom_mean_iou: 0.8718 - val_loss: 0.2277 - val_custom_mean_iou: 0.8233 - lr: 1.0000e-05
# Epoch 146/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1475 - custom_mean_iou: 0.8705
# Epoch 146: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1475 - custom_mean_iou: 0.8705 - val_loss: 0.2273 - val_custom_mean_iou: 0.8196 - lr: 1.0000e-05
# Epoch 147/500
# 69/69 [==============================] - ETA: 0s - loss: 0.1574 - custom_mean_iou: 0.8701
# Epoch 147: val_custom_mean_iou did not improve from 0.83280
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1574 - custom_mean_iou: 0.8701 - val_loss: 0.2257 - val_custom_mean_iou: 0.8227 - lr: 1.0000e-05
# CPU times: total: 42min 30s
# Wall time: 12min 9s

# %%
n_epochs = len(history.history['loss'])

acc = history.history['custom_mean_iou']
val_acc = history.history['val_custom_mean_iou']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(n_epochs) #change it based on epoch needed to finish building the model

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

labels, counts = np.unique(y, return_counts=True)
labels = labels -1
classes = ['Forest','Plantation','Agriculture', 'Shrubland', 'Bareland', 'Urban', 'Waterbody']

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)
score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred, labels=labels)

# plot the confusion matrix of LGB
dl_cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(dl_cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)


# Show all labels
ax.set(xticks=np.arange(dl_cm.shape[1]),
        yticks=np.arange(dl_cm.shape[0]),
        # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,
        title='Normalized Confusion Matrix',
        ylabel='True label',
        xlabel='Predicted label')

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
          rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
fmt = '.2f'
thresh = dl_cm.max() / 2.
for i in range(dl_cm.shape[0]):
    for j in range(dl_cm.shape[1]):
        ax.text(j, i, format(dl_cm[i, j], fmt),
                ha="center", va="center",
                color="white" if dl_cm[i, j] > thresh else "black")
fig.tight_layout()

# %%
# Calculate per-class IoU and mean IoU from raw confusion matrix
def calculate_iou_from_cm(cm):
    n_classes = cm.shape[0]
    class_iou = np.zeros(n_classes)
    
    for i in range(n_classes):
        # True positives: diagonal elements
        tp = cm[i, i]
        
        # False positives: sum of column i minus diagonal element
        fp = np.sum(cm[:, i]) - tp
        
        # False negatives: sum of row i minus diagonal element
        fn = np.sum(cm[i, :]) - tp
        
        # IoU calculation
        if tp + fp + fn == 0:
            class_iou[i] = 0
        else:
            class_iou[i] = tp / (tp + fp + fn)
    
    # Calculate mean IoU
    mean_iou = np.mean(class_iou)
    
    return class_iou, mean_iou

# Use your raw confusion matrix (before normalization)
class_iou, mean_iou = calculate_iou_from_cm(cm)  # 'cm' is your raw confusion matrix

print("Class IoU values:")
for i, class_name in enumerate(classes):
    print(f"{class_name}: {class_iou[i]:.4f}")
print(f"Mean IoU: {mean_iou:.4f}")

# %%
#Metric Precision, Recall, F-score support
from sklearn.metrics import precision_recall_fscore_support

y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)

macro_01 = precision_recall_fscore_support(y_test, y_pred, average='macro')
weighted_01 = precision_recall_fscore_support(y_test, y_pred, average='weighted')

print(macro_01)
print(weighted_01)

# %%
#Metric F1-score
from sklearn.metrics import f1_score

macro_02 = f1_score(y_test, y_pred, average='macro')
weighted_02 = f1_score(y_test, y_pred, average='weighted')

print(macro_02)
print(weighted_02)

# %%
# Print the precision and recall, among other metrics
from sklearn import metrics
from tensorflow.compat.v1.keras.models import load_model

# model = load_model('D:/Wiltang_2022/Paper_Data_Codes/Saved_Model/LC_Multivariate_Wonosobo_BiGRU_exp_ver01_metricmeasurement.h5')
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# y_test = y_test.argmax(axis=1)

print(metrics.classification_report(y_test, y_pred, digits=4))

# %%
import numpy as np
from sklearn.metrics import jaccard_score

y_pred_train = model.predict(X_train)
y_pred_train = y_pred_train.argmax(axis=1)
y_train = y_train.argmax(axis=1)

JS_test = jaccard_score(y_test, y_pred, average='macro')
JS_train = jaccard_score(y_train, y_pred_train, average='macro')
print(JS_test)
print(JS_train)

# %%
import numpy as np
from sklearn.metrics import jaccard_score

y_pred_train = model.predict(X_train)
y_pred_train = y_pred_train.argmax(axis=1)
# y_train = y_train.argmax(axis=1)

JS_test = jaccard_score(y_test, y_pred, average=None)
JS_train = jaccard_score(y_train, y_pred_train, average=None)
print(JS_test)
print(JS_train)

# %%
from sklearn.metrics import cohen_kappa_score

model_kappa = cohen_kappa_score(y_pred, y_test)
print(model_kappa)

# %%
# data_test = {'ytest': y_test,
#         'ytest_pred': y_pred}

# data_train = {'ytest': y_train,
#         'ytest_pred': y_pred_train}

# df_test = pd.DataFrame(data_test)
# df_train = pd.DataFrame(data_train)

# df_test.to_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/df_test.csv')
# df_train.to_csv('D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/df_train.csv')

# %%
# from tensorflow.keras.utils import plot_model
# import pydot
# import pydotplus
# from pydotplus import graphviz

# plot_model(model, to_file='D:/DL_DASCitarum/Spasial_Vector/DAS_Citarum_Extract_Landsat/Saved_Model/model3_plot.png', 
#            show_shapes=True, show_layer_names=True)
